# %% [markdown]
# [출처 : 파이썬 데이터전처리 실습](https://wikidocs.net/86293)

# %%
from IPython.display import Image

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
'''
파이썬의 대표적인 시각화 도구로는 matplotlib과 seaborn이 있습니다. seaborn은 matplotlib 대비 손쉽게 그래프를 
그리고 그래프 스타일 설정을 할 수 있다는 장점이 있습니다. 
정교하게 그래프의 크기를 조절하거나 각 축의 범례 값을 조절할 때에는 matplotlib을 함께 사용해야하지만,
 seaborn 사용법에 익숙해진다면 큰 문제가 되진 않습니다.
'''
# Out:
# '\n파이썬의 대표적인 시각화 도구로는 matplotlib과 seaborn이 있습니다. seaborn은 matplotlib 대비 손쉽게 그래프를 \n그리고 그래프 스타일 설정을 할 수 있다는 장점이 있습니다. \n정교하게 그래프의 크기를 조절하거나 각 축의 범례 값을 조절할 때에는 matplotlib을 함께 사용해야하지만,\n seaborn 사용법에 익숙해진다면 큰 문제가 되진 않습니다.\n'

# %%
Image('image/plot종류.png')

# %%
#seaborn에서 제공하는 flights 데이터 셋을 사용
flights = sns.load_dataset('flights')

#그래프 사이즈 설정
plt.figure(figsize=(12, 3))

# %%
# Barplot
sns.barplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
# violineplot
sns.violinplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
# swarmplot
sns.swarmplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
# Lineplot
sns.lineplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
# Distplot
sns.distplot(flights['passengers'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='passengers', ylabel='Density'>
