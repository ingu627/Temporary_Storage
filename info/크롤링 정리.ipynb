# %%
import urllib.request as req
import urllib.parse as up

# %%
url= 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp'

# %%
myarg={'stnId':'184'}

# %%
params=up.urlencode(myarg) #딕셔너리의 저장된 데이터를 읽어서 키=값 으로 반환
addr=url+'?'+params

# %%
addr
# Out:
# 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=184'

# %%
res=req.urlopen(addr).read()
# 클라이언트 -> 서버로 요청 -> 답변(200(정상), 40x(주소오류), 50x(서버오류))
# 이 메시지가 HTTPResponse 객체로 반환
# 서버는 클라이언트에게 메인페이지의 코드를 전송

# %%
text=res.decode('utf-8')
print(text)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2021년 08월 15일 (일)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>제주도 육상 중기예보 - 2021년 08월 15일 (일)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</guid>
# <description>
# 	<header>
# 		<title>제주도 육상중기예보</title>
# 		<tm>202108150600</tm>
# 		<wf><![CDATA[○ (강수) 기압골의 영향으로 19일(목)오후~24일(화)은 비가 오겠습니다.<br />○ (기온) 이번 예보기간 기온은 어제(14일, 아침최저기온 22~23도, 낮최고기온 23~24도)보다 높겠습니다.<br />○ (해상) 이번 예보기간 동안 제주도해상과 남해서부해상은 1~3m로 일겠습니다.<br /><br />* 이번 예보기간에는 북태평양고기압과 기압골의 위치에 따라 강수의 변동성이 있겠으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.]]></wf>
# 	</header>
# 	<body>
#
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>제주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 00:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-23 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-24 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-25 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>서귀포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 00:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-23 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-24 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-25 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>성산</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 00:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-23 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-24 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-25 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>성판악</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>18</tmn>
# 					<tmx>23</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>23</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>18</tmn>
# 					<tmx>24</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>18</tmn>
# 					<tmx>24</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 00:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>18</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>18</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>20</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>20</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>20</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>20</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-23 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-24 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-25 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>21</tmn>
# 					<tmx>25</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>고산</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 00:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-23 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-24 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-25 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>이어도</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>26</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>26</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>27</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>27</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 00:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>27</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>27</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>27</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>27</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-23 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>27</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-24 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>27</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-25 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>28</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>추자도</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-18 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-19 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 00:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-20 12:00</tmEf>
# 					<wf>구름많고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-21 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2021-08-22 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-23 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-24 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2021-08-25 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
#
# 	</body>
# </description>
# </item>
# </channel>
# </rss>

# %%
from bs4 import BeautifulSoup

# %%
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
res= req.urlopen(url)
soup=BeautifulSoup(res, 'html.parser') # parser는 보기좋게 만들어줌

# %%
soup #분석 가능한 형태의 문석 객체
soup.find('title')
soup.find('title').string
# Out:
# '기상청 육상 중기예보'

# %%
wf=soup.find('wf').string
#여기에다가 정규표현식 작성(한글만..숫자만..)
wf
# Out:
# '○ (강수) 18일(수)은 강원영동에 비가 오겠고, 충청권과 전라권, 경북권에는 소나기가 오는 곳이 있겠습니다. <br />          19일(목)~20일(금) 제주도와 전남권, 경상권에 비가 오겠고, 21일(토)~25일(수)은 전국(강원영동 제외)에 비가 오는 날이 많겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 19~26도, 낮 기온은 27~32도로 어제(14일, 아침최저기온 22~25도, 낮최고기온 25~31도)와 비슷하겠습니다.<br /><br />* 이번 예보기간에는 북태평양고기압과 기압골 위치에 따라 강수의 변동성이 있겠으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.'

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://apis.data.go.kr/B552657/ErmctInfoInqireService/getEmrrmRltmUsefulSckbdInfoInqire'

sidos = ['서울특별시', '부산광역시', '인천광역시', '대구광역시', '광주광역시', '대전광역시', '울산광역시',
'경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도',
'세종특별자치시' ]

for sido in sidos:
    queryParams = '?' + '&ServiceKey=' + 'sDDx7qUKhfoBuzwVrOBez9MhUkvl%2B1Wnwaw7VaqNCfRa5KJ1R%2B2qf%2BSEHZgXUtZpscMDGwBV6CcN9RCtZSoZUQ%3D%3D' \
        + '&STAGE1=' + f'{sido}' \
        # + '&STAGE2=' + '영등포구' \
        # + '&pageNo=' + '1' \
        # + '&numOfRows=' + '10'

    url = url + queryParams

    result = requests.get(url)
    print(result.content)
    bs_obj = BeautifulSoup(result.content, 'html.parser')
    # print(bs_obj)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><dutyName>\xec\x97\xb0\xec\x84\xb8\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90\xec\x9d\x98\xea\xb3\xbc\xeb\x8c\x80\xed\x95\x99\xea\xb0\x95\xeb\x82\xa8\xec\x84\xb8\xeb\xb8\x8c\xeb\x9e\x80\xec\x8a\xa4\xeb\xb3\x91\xec\x9b\x90</dutyName><dutyTel3>02-2019-3333</dutyTel3><hpid>A1100015</hpid><hv1>0</hv1><hv10>Y</hv10><hv11>Y</hv11><hv12>0</hv12><hv2>0</hv2><hv3>0</hv3><hv4>0</hv4><hv5>Y</hv5><hv6>2</hv6><hv7>Y</hv7><hv8>0</hv8><hv9>0</hv9><hvamyn>Y</hvamyn><hvangioayn>N</hvangioayn><hvcc>0</hvcc><hvccc>0</hvccc><hvctayn>Y</hvctayn><hvec>-1</hvec><hvgc>129</hvgc><hvicc>4</hvicc><hvidate>20210815230016</hvidate><hvmriayn>Y</hvmriayn><hvncc>3</hvncc><hvoc>23</hvoc><hvventiayn>Y</hvventiayn><phpid>A1100015</phpid><rnum>1</rnum></item><item><dutyName>\xec\x82\xbc\xec\x84\xb1\xec\x84\x9c\xec\x9a\xb8\xeb\xb3\x91\xec\x9b\x90</dutyName><dutyTel3>02-3410-2060</dutyTel3><hpid>A1100010</hpid><hv1>0</hv1><hv10>Y</hv10><hv11>Y</hv11><hv12>0</hv12><hv2>2</hv2><hv3>7</hv3><hv4>0</hv4><hv5>Y</hv5><hv6>7</hv6><hv7>Y</hv7><hv8>0</hv8><hv9>0</hv9><hvamyn>Y</hvamyn><hvangioayn>N</hvangioayn><hvcc>0</hvcc><hvccc>17</hvccc><hvctayn>Y</hvctayn><hvec>17</hvec><hvgc>235</hvgc><hvicc>5</hvicc><hvidate>20210815230031</hvidate><hvmriayn>Y</hvmriayn><hvncc>5</hvncc><hvoc>56</hvoc><hvventiayn>Y</hvventiayn><phpid>A1100010</phpid><rnum>2</rnum></item><item><dutyName>\xea\xb0\x95\xeb\x8f\x99\xea\xb2\xbd\xed\x9d\xac\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90\xec\x9d\x98\xeb\x8c\x80\xeb\xb3\x91\xec\x9b\x90</dutyName><dutyTel3>02-440-8282</dutyTel3><hpid>A1100043</hpid><hv1>0</hv1><hv10>Y</hv10><hv11>Y</hv11><hv12>0</hv12><hv2>0</hv2><hv3>0</hv3><hv4>0</hv4><hv5>Y</hv5><hv6>0</hv6><hv7>Y</hv7><hv8>0</hv8><hv9>0</hv9><hvamyn>Y</hvamy