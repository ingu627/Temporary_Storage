# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# plot에 나타나는 소수를 3재 짜리까지 나타내줌 
# %precision 3 
pd.set_option('precision', 3)

# %matplotlib inline

# %%
# 한글 깨짐 방지 코드
import matplotlib
from matplotlib import font_manager, rc
import platform
if platform.system()=="Windows":
    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus']=False

import warnings
warnings.filterwarnings("ignore")

# %%
array =np.array([2,3,5,10]) # y값
# x값은 [0,1,2,3]이 자동으로 만들어짐
# (0,2), (1,3), (2, 5), (3, 10)
# plot : 선 또는 마커 그래프를 그릴 때 사용하느 함수 
plt.plot(array)
plt.ylabel('Y값') # label은 이름표

plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9, 16])

# %%
data_dict = [[1,2,3,4], [1,4,9,16]]

plt.plot(data_dict[0], data_dict[1])

# %%
data_dict = {'data_x': [1,2,3,4], 'data_y': [1,4,9, 16]}

plt.plot('data_x', 'data_y', data=data_dict)
plt.show()

# %%
data_dict = [[1,2,3,4], [1,4,9,16]]
# r = red, o = 원형
plt.plot(data_dict[0], data_dict[1], 'ro')
# axis : x,y축이 표시되는 범위를 지정할 수 있다.
# : [xmin, xmax, ymin, ymax] 4개를 반드시 써줘야 한다.

plt.axis([0, 6, 0, 20])
plt.show()

# %%
t= np.arange(0., 5., 0.2)
# x값, y값, x값, y값, x값, y 값
# s= square 사각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^', t, t**4)
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,3], label='나는야')
plt.plot([1,2,3,4], [2,5,10,4], label='너는야')
plt.xlabel('X값', loc='left') #그래프의 축에 레이블을 표시하기
plt.ylabel('Y값', loc='center') # default : center
plt.xlim([0, 5]) # xlim = X축의 범위 
plt.ylim([0,15])
plt.legend(loc='lower left')

plt.show()

# %%
plt.plot([3,5,9,7], '#e377c2')

# %%
x = [1,2,3,4]
y=[1,4,9,3]

plt.plot(x,y)
plt.xlabel('X값')
plt.ylabel('Y값')
plt.fill_between(x[1:3], y[1:3], alpha=0.5)

# %%
x = [1,2,3,4]
y=[1,4,9,3]

plt.plot(x,y)
plt.xlabel('X값')
plt.ylabel('Y값')
plt.fill_betweenx(y[1:3], x[1:3], alpha=0.5)

# %%
t= np.arange(0., 5., 0.2)
# x값, y값, x값, y값, x값, y 값
# s= square 사각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.grid(True, color='red')

# %%
a=np.arange(1.,5.,0.2)
plt.figure(figsize=(10,8)) # figure = 형상, 그릇 
# figsize
# plt.plot(a, a**3, 'g^--')
label = ['zero','one', 'three','six','eight']
plt.plot(a, a**3, color='#e377c2', marker='^', linestyle='--' )
plt.xticks([0,1, 3,6,8], labels=label)
plt.yticks([0,50,100], labels=['zero', 'fifty', 'hundred'])
plt.tick_params(axis='both', labelsize=20, direction='inout', labelcolor='green')

plt.title('간단한 그래프', loc='right', pad=20, fontsize=16, fontweight='bold')
# plt.tick_params는 눈금의 스타일을 다양하게 설정가능
# Out:
# Text(1.0, 1.0, '간단한 그래프')

# %%
t= np.arange(0., 5., 0.2)

plt.figure(figsize=(10,10))
# x값, y값, x값, y값, x값, y 값
# s= square 사각형
plt.plot(t, t, 'r--', t, t**2, 'bs')
plt.plot(t, -2*t+3, 'g:')

plt.hlines(10, 1, 2.5) # hlines(y값으로 수평선의 위치, xmin, xmax )
# plt.axhline(15, 0, 1)

# hlines : 지정한 점을 따라 수평선을 표시한다.
# axhline : 축을 따라 수평선을 표시한다. x의 범위 (0 ~ 1)

plt.vlines(3, 0, 10, color='gray', linestyle=':')
plt.axvline(4, 0, 0.5, linewidth=3, linestyle='-.')

# %%
t= np.arange(0., 5., 0.2)

plt.figure(figsize=(10,10))
# x값, y값, x값, y값, x값, y 값
# s= square 사각형
plt.plot(t, t, 'r', t, t**2, 'bs')
plt.plot(t, -2*t+3, 'g')

plt.axhline(10,0,0.65, linestyle='--')
plt.axvline(3.2,0,0.55, linestyle='--')

# %%
x = np.linspace(-10,10,100) # np.linspace(최소범위, 최대범위, 간격갯수  )
y = x ** 3 

plt.plot(x, y)

# %% [markdown]
# ---

# %% [markdown]
# ### 막대 그래프 : 범주가 있는 데이터 값을 직사각형의 막대로 표현하는 그래프

# %%
y= np.arange(3)

years = ['2017', '2018', '2019']
values= [100, 400, 900]
colors = ['y', 'dodgerblue', 'C2']

plt.figure(figsize=(8,8))
plt.barh(y, values, color=colors, height=0.6, edgecolor='gray', linewidth=5)
plt.yticks(y, labels=years) # 데이터 : x, 레이블 : years
plt.tick_params(axis='y', labelcolor='green')

# %% [markdown]
# ### 산점도(scatter plot) : 두 변수의 상관 관계를 직교 좌표계의 평면에 데이터를 점으로 표현한 그래프

# %%
np.random.seed(0)

# %%
N=50

x= np.random.rand(N)
y= np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2

# %%
plt.scatter(x, y, s=area, c=colors, alpha=0.5, cmap='seismic')

# s= size
# c= color
# cmap = 컬러맵에 해당하는 문자열 지정
# PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            # 'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %%
n=100
xmin, xmax, ymin, ymax, zmin, zmax = 0, 20, 0, 20, 0, 50
# xs,ys는 0에서 20사이, zs는 0에서 50 사이의 값을 갖도록 범위를 정해준다.
# color는 0에서 2사이의 값을 갖는 실수이고, 이 값을 통해 각각 다른 색을 표현한다.
cmin, cmax = 0, 2

xs = np.array([(xmax-xmin)*np.random.random_sample() + xmin for i in range(n) ])
ys = np.array([(ymax-ymin)*np.random.random_sample() + ymin for i in range(n) ])
zs = np.array([(zmax-zmin)*np.random.random_sample() + zmin for i in range(n) ])
color = np.array([(cmax-cmin)*np.random.random_sample() + cmin for i in range(n) ])

fig=plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs, ys, zs, c=color, marker='o', s=15, cmap='Greens')

plt.show()

# %% [markdown]
# ### 히스토그램(histogram) : 도수분포표를 그래프로 나타낸 것으로서, 가로축은 계급, 세로축은 도수(횟수나 개수 등)을 나타낸다.

# %%
weight = [68,81,64,56,78,74,61,77,66,68,59,71,
        80,59,67,81,69,73,69,74,70,65]

plt.hist(weight, cumulative=True)
plt.hist(weight, bins=30, cumulative=True)
# Out:
# (array([ 1.,  1.,  1.,  3.,  3.,  3.,  4.,  4.,  4.,  5.,  6.,  6.,  7.,
#          8., 10., 12., 13., 13., 14., 14., 15., 17., 17., 17., 17., 18.,
#         19., 19., 20., 22.]),
#  array([56.   , 56.833, 57.667, 58.5  , 59.333, 60.167, 61.   , 61.833,
#         62.667, 63.5  , 64.333, 65.167, 66.   , 66.833, 67.667, 68.5  ,
#         69.333, 70.167, 71.   , 71.833, 72.667, 73.5  , 74.333, 75.167,
#         76.   , 76.833, 77.667, 78.5  , 79.333, 80.167, 81.   ]),
#  <BarContainer object of 30 artists>)

# %%
ratio = [34, 32, 16, 18]
label = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0, 0.10, 0, 0.10]
color = ['silver', 'gold', 'whitesmoke', 'lightgray']

plt.pie(ratio, labels=label, autopct='%.1f%%', startangle=260,
        explode=explode, colors=color)
# autopct : 부채꼴 안에 표시될 숫자의 형식을 지정 
# startangle : 부채꼴이 그려지는 시작 각도를 설정 
# explode : 부채꼴이 파이 차트의 중심에서 벗어나는 정도를 설정
# Out:
# ([<matplotlib.patches.Wedge at 0x23dec7dfe20>,
# ...
#  [Text(0.8572717691686503, -0.6892641828692773, 'Apple'),
#   Text(0.20837781320031654, 1.1817693036146497, 'Banana'),
#   Text(-1.0691570919182256, 0.25865636044946455, 'Melon'),
#   Text(-0.8091628850125505, -0.8861463905688304, 'Grapes')],
#  [Text(0.4676027831829001, -0.3759622815650603, '34.0%'),
#   Text(0.12155372436685132, 0.6893654271085455, '32.0%'),
#   Text(-0.5831765955917593, 0.14108528751788973, '16.0%'),
#   Text(-0.47201168292398776, -0.5169187278318177, '18.0%')])
