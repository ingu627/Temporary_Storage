# %% [markdown]
# # 토픽 모델링(Topic Modeling)

# %% [markdown]
# * 토픽 모델링은 문서 집합에서 주제를 찾아내기 위한 기술
# * 토픽 모델링은 '특정 주제에 관한 문서에서는 특정 단어가 자주 등장할 것이다'라는 직관을 기반
# * 예를 들어, 주제가 '개'인 문서에서는 개의 품종, 개의 특성을 나타내는 단어가 다른 문서에 비해 많이 등장
# * 주로 사용되는 토픽 모델링 방법은 잠재 의미 분석과 잠재 디리클레 할당 기법이 있음

# %% [markdown]
# ## 잠재 의미 분석(Latent Semantic Analysis)
#
# * 잠재 의미 분석(LSA)은 주로 문서 색인의 의미 검색에 사용
# * 잠재 의미 인덱싱(Latent Semantic Indexing, LSI)로도 알려져 있음
# * LSA의 목표는 문서와 단어의 기반이 되는 잠재적인 토픽을 발견하는 것
# * 잠재적인 토픽은 문서에 있는 단어들의 분포를 주도한다고 가정
#
# * LSA 방법
#   + 문서 모음에서 생성한 문서-단어 행렬(Document Term Matrix)에서 단어-토픽 행렬(Term-Topic Matrix)과 토픽-중요도 행렬(Topic-Importance Matrix), 그리고 토픽-문서 행렬(Topic-Document Matrix)로 분해

# %% [markdown]
# ## 잠재 디리클레 할당(Latent Dirichlet Allocation)

# %% [markdown]
# * 잠재 디레클레 할당(LDA)은 대표적인 토픽 모델링  알고리즘 중 하나
#
# * 잠재 디레클레 할당 방법
#   1. 사용자가 토픽이 개수를 지정해 알고리즘에 전달
#   2. 모든 단어들을 토픽 중 하나에 할당
#   3. 모든 문서의 모든 단어에 대해 단어 w가 가정에 의거, $p(t|d)$, $p(w|t)$에 따라 토픽을 재할당, 이를 반복, 이 때 가정은 자신만이 잘못된 토픽에 할당되어 있고 다른 모든 단어는 올바른 토픽에 할당된다는 것을 의미
#
# * $p(t|d)$ - 문서 d의 단어들 중 토픽 t에 해당하는 비율
# * 해당 문서의 자주 등장하는 다른 단어의 토픽이 해당 단어의 토픽이 될 가능성이 높음을 의미
#
# * $p(w|t)$- 단어 w를 가지고 있는 모든 문서들 중  토픽 t가 할당된 비율
# * 다른 문서에서 단어 w에 많이 할당된 토픽이 해당 단어의 토픽이 될 가능성이 높음을 의미

# %% [markdown]
# ## 데이터 준비

# %%
from sklearn.datasets import fetch_20newsgroups

dataset = fetch_20newsgroups(shuffle=True, random_state=1, 
                             remove=('headers', 'footers', 'quotes'))
documents = dataset.data

print(len(documents))
documents[0]
# Out:
# 11314
# "Well i'm not sure about the story nad it did seem biased. What\nI disagree with is your statement that the U.S. Media is out to\nruin Israels reputation. That is rediculous. The U.S. media is\nthe most pro-israeli media in the world. Having lived in Europe\nI realize that incidences such as the one described in the\nletter have occured. The U.S. media as a whole seem to try to\nignore them. The U.S. is subsidizing Israels existance and the\nEuropeans are not (at least not to the same degree). So I think\nthat might be a reason they report more clearly on the\natrocities.\n\tWhat is a shame is that in Austria, daily reports of\nthe inhuman acts commited by Israeli soldiers and the blessing\nreceived from the Government makes some of the Holocaust guilt\ngo away. After all, look how the Jews are treating other races\nwhen they got power. It is unfortunate.\n"

# %%
documents[3]
# Out:
# 'Notwithstanding all the legitimate fuss about this proposal, how much\nof a change is it?  ATT\'s last product in this area (a) was priced over\n$1000, as I suspect \'clipper\' phones will be; (b) came to the customer \nwith the key automatically preregistered with government authorities. Thus,\naside from attempting to further legitimize and solidify the fed\'s posture,\nClipper seems to be "more of the same", rather than a new direction.\n   Yes, technology will eventually drive the cost down and thereby promote\nmore widespread use- but at present, the man on the street is not going\nto purchase a $1000 crypto telephone, especially when the guy on the other\nend probably doesn\'t have one anyway.  Am I missing something?\n   The real question is what the gov will do in a year or two when air-\ntight voice privacy on a phone line is as close as your nearest pc.  That\nhas got to a problematic scenario for them, even if the extent of usage\nnever surpasses the \'underground\' stature of PGP.'

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim.parsing.preprocessing import preprocess_string

nltk.download('stopwords')

def clean_text(d):
  pattern = r'[^a-zA-Z\s]'
  text = re.sub(pattern, '', d)
  return d

def clean_stopword(d):
  stop_words = stopwords.words('english')
  return ' '.join([w.lower() for w in d.split() if w not in stop_words and len(w) > 3])

def preprocessing(d):
  return preprocess_string(d)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd

news_df = pd.DataFrame({'article':documents})
len(news_df)
# Out:
# 11314

# %%
news_df.replace('', float('NaN'), inplace=True)
news_df.isnull().values.any()
news_df.dropna(inplace=True)
print(len(news_df))
# Out:
# 11096

# %%
news_df['article'] = news_df['article'].apply(clean_text)
news_df['article']
# Out:
# 0        Well i'm not sure about the story nad it did s...
# 1        \n\n\n\n\n\n\nYeah, do you expect people to re...
# 2        Although I realize that principle is not one o...
# 3        Notwithstanding all the legitimate fuss about ...
# 4        Well, I will have to change the scoring on my ...
#                                ...
# 11309    Danny Rubenstein, an Israeli journalist, will ...
# 11310                                                   \n
# 11311    \nI agree.  Home runs off Clemens are always m...
# 11312    I used HP DeskJet with Orange Micros Grappler ...
# 11313                                          ^^^^^^\n...
# Name: article, Length: 11096, dtype: object

# %%
news_df['article'] = news_df['article'].apply(clean_stopword)
news_df['article']
# Out:
# 0        well sure story seem biased. what disagree sta...
# 1        yeah, expect people read faq, etc. actually ac...
# 2        although realize principle strongest points, w...
# 3        notwithstanding legitimate fuss proposal, much...
# 4        well, change scoring playoff pool. unfortunate...
#                                ...
# 11309    danny rubenstein, israeli journalist, speaking...
# 11310
# 11311    agree. home runs clemens always memorable. kin...
# 11312    used deskjet orange micros grappler system6.0....
# 11313    ^^^^^^ argument murphy. scared hell came last ...
# Name: article, Length: 11096, dtype: object

# %%
tokenized_news = news_df['article'].apply(preprocessing)
tokenized_news = tokenized_news.to_list()
tokenized_news
# Out:
# [['sure',
#   'stori',
#   'bias',
#   'disagre',
#   'statement',
#   'media',
#   'ruin',
#   'israel',
#   'reput',
#   'redicul',
#   'media',
#   'pro',
#   'isra',
#   'media',
#   'world',
#   'have',
#   'live',
#   'europ',
#   'realiz',
#   'incid',
#   'describ',
#   'letter',
#   'occur',
#   'media',
#   'ignor',
#   'subsid',
#   'israel',
#   'exist',
#   'european',
#   'degre',
#   'think',
#   'reason',
#   'report',
#   'clearli',
#   'atroc',
#   'shame',
#   'austria',
#   'daili',
#   'report',
#   'inhuman',
#   'act',
#   'commit',
#   'isra',
#   'soldier',
#   'bless',
#   'receiv',
#   'govern',
#   'make',
#   'holocaust',
#   'guilt',
#   'awai',
#   'look',
#   'jew',
#   'treat',
#   'race',
#   'power',
#   'unfortun'],
#  ['yeah',
#   'expect',
#   'peopl',
#   'read',
#   'faq',
#   'actual',
#   'accept',
#   'hard',
#   'atheism',
#   'need',
#   'littl',
#   'leap',
#   'faith',
#   'jimmi',
#   'logic',
#   'run',
#   'steam',
#   'jim',
#   'sorri',
#   'piti',
#   'jim',
#   'sorri',
#   'feel',
#   'denial',
#   'faith',
#   'need',
#   'pretend',
#   'happili',
#   'mayb',
#   'start',
#   'newsgroup',
#   'alt',
#   'atheist',
#   'hard',
#   'bummin',
#   'bye',
#   'bye',
#   'jim',
#   'forget',
#   'flintston',
#   'chewabl',
#   'bake',
#   'timmon'],
#  ['realiz',
#   'principl',
#   'strongest',
#   'point',
#   'like',
#   'know',
#   'question',
#   'sort',
#   'arab',
#   'countri',
#   'want',
#   'continu',
#   'think',
#   'tank',
#   'charad',
#   'fixat',
#   'israel',
#   'stop',
#   'start',
#   'ask',
#   'sort',
#   'question',
#   'arab',
#   'countri',
#   'realiz',
#   'work',
#   'arab',
#   'countri',
#   'treatment',
#   'jew',
#   'decad',
#   'fixat',
#   'israel',
#   'begin',
#   'look',
#   'like',
#   'bias',
#   'attack',
#   'group',
#   'recogn',
#   'stupid',
#   'center',
#   'polici',
#   'research',
#   'fanci',
#   'bigot',
#   'hate',
#   'israel'],
#  ['notwithstand',
#   'legitim',
#   'fuss',
#   'propos',
#   'chang',
#   'att',
#   'product',
#   'area',
#   'price',
#   'suspect',
#   'clipper',
#   'phone',
#   'came',
#   'custom',
#   'automat',
#   'preregist',
#   'govern',
#   'author',
#   'asid',
#   'attempt',
#   'legitim',
#   'solidifi',
#   'fed',
#   'postur',
#   'clipper',
#   'direct',
#   'ye',
#   'technolog',
#   'eventu',
#   'drive',
#   'cost',
#   'promot',
#   'widespread',
#   'us',
#   'present',
#   'street',
#   'go',
#   'purchas',
#   'crypto',
#   'telephon',
#   'especi',
#   'probabl',
#   'miss',
#   'real',
#   'question',
#   'year',
#   'air',
#   'tight',
#   'voic',
#   'privaci',
#   'phone',
#   'line',
#   'close',
#   'nearest',
#   'problemat',
#   'scenario',
#   'extent',
#   'usag',
#   'surpass',
#   'underground',
#   'statur',
#   'pgp'],
#  ['chang',
#   'score',
#   'playoff',
#   'pool',
#   'unfortun',
#   'time',
#   'right',
#   'certainli',
#   'post',
#   'score',
#   'rule',
#   'tomorrow',
#   'matter',
#   'enter',
#   'good',
#   'keith',
#   'keller',
#   'let',
#   'ranger',
#   'let',
#   'quaker',
#   'kkeller',
#   'mail',
#   'sa',
#   'upenn',
#   'edu',
#   'leagu',
#   'champ'],
#  ['read',
#   'think',
#   'morton',
#   'smith',
#   'jesu',
#   'magician',
#   'lazaru',
#   'dead',
#   'go',
#   'tomb',
#   'initi',
#   'rite',
#   'magi',
#   'cult',
#   'jesu',
#   'appear',
#   'dai',
#   'stai',
#   'normal',
#   'wonder'],
#  ['record',
#   'show',
#   'iisi',
#   'cach',
#   'small',
#   'attach',
#   'measur',
#   'real',
#   'program',
#   'cach',
#   'speedup',
#   'vari',
#   'app',
#   'rang',
#   'think',
#   'averag',
#   'right',
#   'subject',
#   'differ',
#   'great',
#   'notic',
#   'simpl',
#   'cach',
#   'card',
#   'certainli',
#   'transform',
#   'iisi',
#   'enorm',
#   'better',
#   'fpu',
#   'convent',
#   'wisdom',
#   'sai',
#   'cach',
#   'card',
#   'maker',
#   'offer',
#   'speedup',
#   'differ',
#   'cach',
#   'bought',
#   'wave',
#   'absolut',
#   'problem',
#   'complet',
#   'speedomet',
#   'run',
#   'cach',
#   'like',
#   'let',
#   'check',
#   'convent',
#   'wisdom',
#   'call',
#   'perform',
#   'rate',
#   'number',
#   'cheer',
#   'file',
#   'convert',
#   'binhex',
#   'kbfkp',
#   'bgj',
#   'cfgigfh',
#   'ghq',
#   'qsqbuc',
#   'squu',
#   'qscfphghl',
#   'hcl',
#   'kjqtu',
#   'ldh',
#   'hbl',
#   'ucucj',
#   'gqhgik',
#   'hcakrspij',
#   'qrq',
#   'quj',
#   'ucld',
#   'quutqc',
#   'dlj',
#   'quubut',
#   'qj',
#   'qj',
#   'tuuqcq',
#   'ucfj',
#   'cacsl',
#   'cqfm',
#   'vxmhha',
#   'irdjpcvr',
#   'lucvszsij',
#   'jpi',
#   'lzqa',
#   'alxrhjf',
#   'aztvl',
#   'eap',
#   'rei',
#   'vipiqkfdk',
#   'tlkcxzlghf',
#   'lkh',
#   'qhhmilc',
#   'qiq',
#   'gesp',
#   'ejn',
#   'bhmdhll',
#   'qbqsrmm',
#   'jpgxqcprryreyd',
#   'hrj',
#   'pclhrsgpfeiymcrisefp',
#   'cge',
#   'trafa',
#   'qka',
#   'pgjk',
#   'femcbikfqc',
#   'bddt',
#   'xpz',
#   'vldfeuvk',
#   'jad',
#   'fza',
#   'ezr',
#   'egtyknxhsjfei',
#   'btbhjlexpekj',
#   'zkh',
#   'khgzc',
#   'bhhnv',
#   'dcxd',
#   'sdfd',
#   'cxhkel',
#   'pyyi',
#   'frg',
#   'jmrjtcymibkbb',
#   'pubq',
#   'mmihg',
#   'eung',
#   'msap',
#   'dinq',
#   'mqjza',
#   'mimq',
#   'feu',
#   'yuexb',
#   'rae',
#   'padk',
#   'cak',
#   'easthliahf',
#   'vir',
#   'qqd',
#   'mmidhhmfruqek',
#   'rqj',
#   'yiql',
#   'qhh',
#   'zkxi',
#   'pqrqkcu',
#   'edr',
#   'qciuk',
#   'zmef',
#   'iyi',
#   'bqmeffktbb',
#   'jhylk',
#   'pxveb',
#   'uamd',
#   'iejf',
#   'ppzc',
#   'hajcybr',
#   'jdm',
#   'scjh',
#   'qetfvkrr',
#   'zviq',
#   'bfr',
#   'juji',
#   'rcdpaxafrl',
#   'xrhf',
#   'dmvi',
#   'fnmlpjd',
#   'qbckeh',
#   'kiara',
#   'nta',
#   'yyltm',
#   'bufflgj',
#   'dqa',
#   'euqsj',
#   'clefr',
#   'kpdgj',
#   'bijhnadh',
#   'mrm',
#   'qpjiteram',
#   'rhj',
#   'rjjxdke',
#   'cabdk',
#   'jkrqr',
#   'icrc',
#   'krd',
#   'mvrbjcx',
#   'frchypk',
#   'rchjjij',
#   'jpq',
#   'ffv',
#   'kgqg',
#   'mbmupgxkuex',
#   'khrx',
#   'fixirnykb',
#   'rsbn',
#   'mqpqrad',
#   'fhrc',
#   'peirfhi',
#   'rjjxbf',
#   'cljkfbqgmmclee',
#   'mhpfbarq',
#   'plk',
#   'qrmm',
#   'cpjy',
#   'ddapal',
#   'eipbdc',
#   'pexj',
#   'hfz',
#   'zkgnha',
#   'rdf',
#   'vbkj',
#   'tlp',
#   'qckrpm',
#   'jebn',
#   'jhn',
#   'pqxjnlyrlpqc',
#   'cmle',
#   'cxz',
#   'mpv',
#   'xtbfqasr',
#   'xrmrzfilxsv',
#   'ppvjicfmrrekxddi',
#   'fhmt',
#   'aalmchgur',
#   'meyaridi',
#   'ylpehpai',
#   'fhnfmq',
#   'qlchvc',
#   'duajj',
#   'ndih',
#   'jqed',
#   'xcgdtvmdy',
#   'mrjer',
#   'aacvkc',
#   'lzi',
#   'pzk',
#   'vrd',
#   'hfr',
#   'mci',
#   'nqhr',
#   'jve',
#   'abfb',
#   'qqlk',
#   'lkqrh',
#   'mkhnya',
#   'qhq',
#   'kajhrefqr',
#   'hbz',
#   'slfg',
#   'tpmif',
#   'pcdemb',
#   'jjt',
#   'admicj'],
#  ['sound',
#   'like',
#   'wish',
#   'guess',
#   'call',
#   'mean',
#   'peac',
#   'process',
#   'palestinean',
#   'negoci',
#   'found',
#   'predict',
#   'know',
#   'found',
#   'test',
#   'tabl',
#   'month',
#   'prove',
#   'fault',
#   'right',
#   'know',
#   'let',
#   'palestinean',
#   'want',
#   'israel',
#   'known',
#   'accept',
#   'term',
#   'isra',
#   'mayb',
#   'palestinenan',
#   'readi',
#   'statehood',
#   'mayb',
#   'polit',
#   'palestinean',
#   'leadership',
#   'fraction',
#   'sai',
#   'reason',
#   'real',
#   'arab',
#   'stall',
#   'negoti',
#   'like',
#   'california',
#   'orang',
#   'feel',
#   'sharper',
#   'tabl',
#   'regard'],
#  ['sai',
#   'allow',
#   'msg',
#   'forc',
#   'food',
#   'want',
#   'enhanc',
#   'tabl',
#   'like',
#   'salt',
#   'option',
#   'eater',
#   'commer',
#   'product',
#   'leav',
#   'includ',
#   'packet',
#   'like',
#   'salt',
#   'packet',
#   'desir',
#   'salt',
#   'pepper',
#   'mustard',
#   'ketchup',
#   'pickl',
#   'tabl',
#   'option',
#   'treat',
#   'wai',
#   'shove',
#   'condiment',
#   'throat',
#   'shove'],
#  ['wonder',
#   'shed',
#   'light',
#   'electron',
#   'odomet',
#   'rememb',
#   'total',
#   'elaps',
#   'mileag',
#   'kind',
#   'memori',
#   'stabl',
#   'reliabl',
#   'non',
#   'volatil',
#   'independ',
#   'outsid',
#   'batteri',
#   'power',
#   'year',
#   'life',
#   'vehicl',
#   'amaz',
#   'like',
#   'expect',
#   'work',
#   'length',
#   'time',
#   'especi',
#   'light',
#   'gizmo',
#   'work',
#   'good',
#   'work',
#   'month',
#   'break',
#   'question',
#   'legal',
#   'ramif',
#   'sell',
#   'replac',
#   'odomet',
#   'start',
#   'mile',
#   'actual',
#   'mile',
#   'look',
#   'like',
#   'fraud',
#   'fairli',
#   'easi',
#   'price',
#   'odomet',
#   'mile',
#   'want',
#   'tell',
#   'buyer',
#   'thank',
#   'insight'],
#  ['archiv',
#   'graphic',
#   'resourc',
#   'list',
#   'modifi',
#   'graphic',
#   'resourc',
#   'list',
#   'weekli',
#   'post',
#   'chang',
#   'april',
#   'faq',
#   'includ',
#   'list',
#   'avail',
#   'archiv',
#   'site',
#   'pit',
#   'manag',
#   'mit',
#   'edu',
#   'alia',
#   'rtfm',
#   'mit',
#   'edu',
#   'directori',
#   'pub',
#   'usenet',
#   'new',
#   'answer',
#   'archiv',
#   'appear',
#   'archiv',
#   'line',
#   'articl',
#   'archiv',
#   'graphic',
#   'resourc',
#   'list',
#   'mail',
#   'server',
#   'machin',
#   'send',
#   'mail',
#   'messag',
#   'mail',
#   'server',
#   'pit',
#   'manag',
#   'mit',
#   'edu',
#   'contain',
#   'keyword',
#   'help',
#   'quot',
#   'messag',
#   'bodi',
#   'place',
#   'list',
#   'item',
#   'place',
#   'resourc',
#   'list',
#   'inform',
#   'item',
#   'chang',
#   'arrang',
#   'subject',
#   'order',
#   'better',
#   'articl',
#   'limit',
#   'plan',
#   'chang',
#   'header',
#   'soon',
#   'care',
#   'resourc',
#   'list',
#   'kei',
#   'sure',
#   'remain',
#   'subject',
#   'line',
#   'place',
#   'resourc',
#   'list',
#   'graphic',
#   'editor',
#   'public',
#   'domain',
#   'free',
#   'sharewar',
#   'system',
#   'plot',
#   'packag',
#   'molecular',
#   'visual',
#   'stuff',
#   'think',
#   'make',
#   'post',
#   'weekli',
#   'think',
#   'line',
#   'chang',
#   'charact',
#   'ad',
#   'line',
#   'prepend',
#   'remov',
#   'line',
#   'remov',
#   'diff',
#   'locat',
#   'chang',
#   'text',
#   'copyright',
#   'nikolao',
#   'foti',
#   'copi',
#   'freeli',
#   'file',
#   'provid',
#   'copyright',
#   'notic',
#   'intact',
#   'compil',
#   'nikolao',
#   'nick',
#   'foti',
#   'mail',
#   'nfoti',
#   'thesea',
#   'ntua',
#   'contact',
#   'updat',
#   'correct',
#   'disclaim',
#   'guarante',
#   'accuraci',
#   'document',
#   'risk',
#   'mainli',
#   'guid',
#   'graphic',
#   'softwar',
#   'suggest',
#   'read',
#   'comp',
#   'graphic',
#   'imag',
#   'analysi',
#   'stuff',
#   'entitl',
#   'date',
#   'comp',
#   'graphic',
#   'frequent',
#   'ask',
#   'question',
#   'faq',
#   'john',
#   'griegg',
#   'poster',
#   'offici',
#   'comp',
#   'graphic',
#   'includ',
#   'comment',
#   'brace',
#   'nikolao',
#   'foti',
#   'content',
#   'resourc',
#   'list',
#   'place',
#   'resourc',
#   'list',
#   'archi',
#   'note',
#   'graphic',
#   'site',
#   'list',
#   'eric',
#   'hain',
#   'mail',
#   'server',
#   'graphic',
#   'orient',
#   'bbse',
#   'rai',
#   'trace',
#   'graphic',
#   'relat',
#   'mail',
#   'list',
#   'graphic',
#   'editor',
#   'public',
#   'domain',
#   'free',
#   'sharewar',
#   'system',
#   'commerci',
#   'system',
#   'scene',
#   'descript',
#   'languag',
#   'solid',
#   'descript',
#   'format',
#   'plot',
#   'packag',
#   'imag',
#   'analysi',
#   'softwar',
#   'imag',
#   'process',
#   'displai',
#   'scene',
#   'gener',
#   'geograph',
#   'data',
#   'map',
#   'data',
#   'file',
#   'scanner',
#   'digit',
#   'data',
#   'background',
#   'imageri',
#   'textur',
#   'datafil',
#   'introduct',
#   'render',
#   'algorithm',
#   'trace',
#   'buffer',
#   'depth',
#   'buffer',
#   'geometr',
#   'data',
#   'teapot',
#   'space',
#   'shuttl',
#   'imag',
#   'annot',
#   'softwar',
#   'scientif',
#   'visual',
#   'stuff',
#   'molecular',
#   'visual',
#   'stuff',
#   'geograph',
#   'inform',
#   'system',
#   'softwar',
#   'futur',
#   'addit',
#   'send',
#   'updat',
#   'info',
#   'place',
#   'resourc',
#   'list',
#   'file',
#   'crosspost',
#   'comp',
#   'graphic',
#   'comp',
#   'answer',
#   'new',
#   'answer',
#   'locat',
#   'comp',
#   'graphic',
#   'advis',
#   'search',
#   'comp',
#   'answer',
#   'new',
#   'answer',
#   'group',
#   'usual',
#   'archiv',
#   'site',
#   'contact',
#   'sysadmin',
#   'info',
#   'articl',
#   'post',
#   'comp',
#   'graphic',
#   'time',
#   'month',
#   'kept',
#   'place',
#   'faq',
#   'includ',
#   'avail',
#   'archiv',
#   'site',
#   'pit',
#   'manag',
#   'mit',
#   'edu',
#   'alia',
#   'rtfm',
#   'mit',
#   'edu',
#   'directori',
#   'pub',
#   'usenet',
#   'new',
#   'answer',
#   'archiv',
#   'appear',
#   'archiv',
#   'line',
#   'articl',
#   'archiv',
#   'graphic',
#   'resourc',
#   'list',
#   'mail',
#   'server',
#   'machin',
#   'send',
#   'mail',
#   'messag',
#   'mail',
#   'server',
#   'pit',
#   'manag',
#   'mit',
#   'edu',
#   'contain',
#   'help',
#   'subject',
#   'field',
#   'inria',
#   'graphlib',
#   'mail',
#   'server',
#   'mirror',
#   'post',
#   'subject',
#   'mail',
#   'server',
#   'resourc',
#   'list',
#   'acces',
#   'wai',
#   'machin',
#   'enuxva',
#   'ea',
#   'asu',
#   'edu',
#   'port',
#   'graphic',
#   'resourc',
#   'list',
#   'digest',
#   'type',
#   'line',
#   'number',
#   'item',
#   'purpos',
#   'index',
#   'place',
#   'monitor',
#   'list',
#   'maasinfo',
#   'file',
#   'info',
#   'contact',
#   'robert',
#   'maa',
#   'place',
#   'search',
#   'faq',
#   'gener',
#   'switch',
#   'swiss',
#   'academ',
#   'research',
#   'network',
#   'switzerland',
#   'interact',
#   'telnet',
#   'nic',
#   'switch',
#   'login',
#   'info',
#   'info',
#   'servic',
#   'usenet',
#   'period',
#   'post',
#   'directori',
#   'search',
#   'index',
#   'file',
#   'type',
#   'word',
#   'look',
#   'read',
#   'faq',
#   'directori',
#   'decid',
#   'fetch',
#   'follow',
#   'method',
#   'ftp',
#   'login',
#   'nic',
#   'switch',
#   'user',
#   'anonym',
#   'enter',
#   'internet',
#   'style',
#   'address',
#   'prompt',
#   'password',
#   'info',
#   'servic',
#   'usenet',
#   'period',
#   'post',
#   'mail',
#   'send',
#   'mail',
#   'rfc',
#   'archiv',
#   'server',
#   'nic',
#   'switch',
#   'archiv',
#   'server',
#   'nic',
#   'switch',
#   'prmd',
#   'switch',
#   'admd',
#   'arcom',
#   'enter',
#   'help',
#   'bodypart',
#   'receiv',
#   'instruct',
#   'inform',
#   'requir',
#   'subject',
#   'header',
#   'line',
#   'archi',
#   'archi',
#   'servic',
#   'locat',
#   'place',
#   'request',
#   'file',
#   'appreci',
#   'archi',
#   'ask',
#   'help',
#   'newsgroup',
#   'archi',
#   'server',
#   'archi',
#   'aussi',
#   'archi',
#   'funet',
#   'finland',
#   'eur',
#   'archi',
#   'darmstadt',
#   'ger',
#   'huji',
#   'israel',
#   'archi',
#   'kui',
#   'kyoto',
#   'japan',
#   'archi',
#   'sogang',
#   'korea',
#   'archi',
#   'ncu',
#   'edu',
#   'telnet',
#   'twn',
#   'archi',
#   'doc',
#   'ireland',
#   'archi',
#   'sura',
#   'net',
#   'usa',
#   'archi',
#   'unl',
#   'edu',
#   'password',
#   'archi',
#   'usa',
#   'archi',
#   'an',
#   'net',
#   'usa',
#   'archi',
#   'rutger',
#   'edu',
#   'usa',
#   'archi',
#   'new',
#   'zealand',
#   'connect',
#   'archi',
#   'server',
#   'telnet',
#   'type',
#   'archi',
#   'usernam',
#   'help',
#   'type',
#   'help',
#   'xarchi',
#   'archi',
#   'client',
#   'archi',
#   'burden',
#   'telnet',
#   'session',
#   'xarchi',
#   'contrib',
#   'tape',
#   'archi',
#   'comp',
#   'sourc',
#   'misc',
#   'vol',
#   'inform',
#   'archi',
#   'mail',
#   'send',
#   'mail',
#   'subject',
#   'help',
#   'archi',
#   'account',
#   'site',
#   'note',
#   'janet',
#   'pss',
#   'user',
#   'unit',
#   'kingdom',
#   'archi',
#   'site',
#   'access',
#   'janet',
#   'host',
#   'doc',
#   'connect',
#   'specifi',
#   'archi',
#   'host',
#   'archi',
#   'usernam',
#   'note',
#   'excerpt',
#   'articl',
#   'post',
#   'mail',
#   'messag',
#   'sai',
#   'ftp',
#   'mail',
#   'number',
#   'autom',
#   'mail',
#   'server',
#   'send',
#   'thing',
#   'like',
#   'respons',
#   'messag',
#   'number',
#   'site',
#   'archiv',
#   'usenet',
#   'sourc',
#   'newsgroup',
#   'avail',
#   'email',
#   'queri',
#   'send',
#   'messag',
#   'autom',
#   'server',
#   'sai',
#   'like',
#   'send',
#   'comp',
#   'sourc',
#   'unix',
#   'fbm',
#   'hour',
#   'dai',
#   'later',
#   'file',
#   'mail',
#   'graphic',
#   'site',
#   'list',
#   'eric',
#   'hain',
#   'graphic',
#   'relat',
#   'site',
#   'maintain',
#   'compil',
#   'eric',
#   'hain',
#   'erich',
#   'ey',
#   'com',
#   'nick',
#   'foti',
#   'nfoti',
#   'thesea',
#   'ntua',
#   'rai',
#   'tracer',
#   'rayshad',
#   'great',
#   'tracer',
#   'workstat',
#   'amiga',
#   'successor',
#   'trace',
#   'written',
#   'compuserv',
#   'question',
#   'drew',
#   'well',
#   'compuserv',
#   'com',
#   'dave',
#   'buck',
#   'david',
#   'buck',
#   'carleton',
#   'tracer',
#   'good',
#   'rang',
#   'surfac',
#   'type',
#   'vort',
#   'packag',
#   'dkbtrace',
#   'good',
#   'tracer',
#   'report',
#   'pc',
#   'amiga',
#   'unix',
#   'preview',
#   'rtrace',
#   'portuges',
#   'tracer',
#   'bicub',
#   'patch',
#   'csg',
#   'text',
#   'do',
#   'version',
#   'djgpp',
#   'extend',
#   'exist',
#   'port',
#   'vivid',
#   'sharewar',
#   'raytrac',
#   'binari',
#   'author',
#   'stephen',
#   'coi',
#   'ssc',
#   'vax',
#   'boe',
#   'com',
#   'sourc',
#   'version',
#   'avail',
#   'regist',
#   'user',
#   'direct',
#   'author',
#   'rai',
#   'steve',
#   'hollasch',
#   'dimension',
#   'tracer',
#   'render',
#   'hyperspher',
#   'hypertetrahedra',
#   'hyperplan',
#   'hyperparallelepip',
#   'separ',
#   'real',
#   'time',
#   'wirefram',
#   'viewer',
#   'written',
#   'call',
#   'wire',
#   'mtv',
#   'qrt',
#   'dbw',
#   'tracer',
#   'interest',
#   'featur',
#   'distribut',
#   'parallel',
#   'raytrac',
#   'xdart',
#   'distribut',
#   'rai',
#   'tracer',
#   'run',
#   'server',
#   'binari',
#   'work',
#   'decstat',
#   'sparc',
#   'snake',
#   'seri',
#   'client',
#   'distribut',
#   'binari',
#   'sourc',
#   'inetrai',
#   'network',
#   'version',
#   'rayshad',
#   'need',
#   'newer',
#   'contact',
#   'andrea',
#   'thurnherr',
#   'ant',
#   'ip',
#   'ethz',
#   'prt',
#   'prai',
#   'parallel',
#   'tracer',
#   'volum',
#   'render',
#   'vrend',
#   'cornel',
#   'volum',
#   'render',
#   'kartch',
#   'devin',
#   'caffei',
#   'warren',
#   'fortran',
#   'radios',
#   'diffus',
#   'light',
#   'render',
#   'radianc',
#   'tracer',
#   'radios',
#   'effect',
#   'greg',
#   'ward',
#   'excel',
#   'shade',
#   'model',
#   'physic',
#   'base',
#   'light',
#   'simul',
#   'unix',
#   'base',
#   'port',
#   'amiga',
#   'india',
#   'indian',
#   'radios',
#   'packag',
#   'base',
#   'radianc',
#   'sgi',
#   'rad',
#   'interact',
#   'radios',
#   'packag',
#   'run',
#   'machin',
#   'spacebal',
#   'includ',
#   'hous',
#   'databas',
#   'author',
#   'moreillon',
#   'simpl',
#   'public',
#   'domain',
#   'radios',
#   'packag',
#   'solut',
#   'stand',
#   'unix',
#   'box',
#   'walk',
#   'requir',
#   'author',
#   'bernard',
#   'kwok',
#   'render',
#   'raytrac',
#   'graphic',
#   'librari',
#   'sipp',
#   'scan',
#   'line',
#   'buffer',
#   'phong',
#   'shade',
#   'render',
#   'us',
#   'shadow',
#   'buffer',
#   'algorithm',
#   'tcl',
#   'sipp',
#   'command',
#   'interfac',
#   'sipp',
#   'render',
#   'program',
#   'tcl',
#   'sipp',
#   'command',
#   'program',
#   'sipp',
#   'write',
#   'compil',
#   'code',
#   'command',
#   'specifi',
#   'surfac',
#   'object',
#   'scene',
#   'render',
#   'option',
#   'render',
#   'format',
#   'utah',
#   'raster',
#   'toolkit',
#   'format',
#   'photo',
#   'widget',
#   'base',
#   'applic',
#   'vogl',
#   'graphic',
#   'learn',
#   'environ',
#   'devic',
#   'portabl',
#   'vogl',
#   'like',
#   'librari',
#   'base',
#   'vogl',
#   'rend',
#   'fast',
#   'polygon',
#   'render',
#   'intel',
#   'version',
#   'photorealist',
#   'real',
#   'time',
#   'render',
#   'xsharp',
#   'dobb',
#   'journal',
#   'render',
#   'sourc',
#   'code',
#   'budget',
#   'textur',
#   'map',
#   'model',
#   'wirefram',
#   'viewer',
#   'vision',
#   'model',
#   'output',
#   'radianc',
#   'rayshad',
#   'file',
#   'irit',
#   'solid',
#   'model',
#   'support',
#   'freeform',
#   'surfac',
#   'wirefram',
#   'viewer',
#   'wirefram',
#   'graphic',
#   'toolkit',
#   'sourc',
#   'object',
#   'stuff',
#   'look',
#   'major',
#   'archiv',
#   'like',
#   'wuarchiv',
#   'file',
#   'dkit',
#   'zip',
#   'pvd',
#   'sharewar',
#   'model',
#   'povrai',
#   'beta',
#   'test',
#   'french',
#   'doc',
#   'price',
#   'regist',
#   'french',
#   'franc',
#   'save',
#   'disabl',
#   'extra',
#   'util',
#   'file',
#   'regist',
#   'version',
#   'geometr',
#   'viewer',
#   'salem',
#   'base',
#   'packag',
#   'dobkin',
#   'explor',
#   'mathemat',
#   'structur',
#   'geomview',
#   'base',
#   'packag',
#   'look',
#   'interact',
#   'manipul',
#   'object',
#   'geometri',
#   'center',
#   'minnesota',
#   'geobench',
#   'experiment',
#   'geometri',
#   'zurich',
#   'workbench',
#   'geometr',
#   'comput',
#   'macintosh',
#   'comput',
#   'wire',
#   'wirefram',
#   'preview',
#   'steve',
#   'hollasch',
#   'rai',
#   'data',
#   'format',
#   'data',
#   'set',
#   'trace',
#   'procedur',
#   'databas',
#   'test',
#   'tracer',
#   'simplist',
#   'file',
#   'format',
#   ...],
#  ['roberto',
#   'clement',
#   'topp',
#   'basebal',
#   'card',
#   'sale',
#   'near',
#   'mint',
#   'condit',
#   'close',
#   'mint',
#   'condit',
#   'list',
#   'recent',
#   'basebal',
#   'card',
#   'pricelist',
#   'offer',
#   'certifi',
#   'postag',
#   'ship'],
#  ['diet',
#   'evangelist',
#   'good',
#   'term',
#   'fit',
#   'atkin',
#   'gordon',
#   'bank',
#   'njxp',
#   'skeptic',
#   'chastiti',
#   'intellect',
#   'geb',
#   'cadr',
#   'dsl',
#   'pitt',
#   'edu',
#   'shame',
#   'surrend',
#   'soon'],
#  ['damon',
#   'matter',
#   'explan',
#   'creation',
#   'wish',
#   'accept',
#   'start',
#   'premis',
#   'creation',
#   'creation',
#   'altern',
#   'accept',
#   'premis',
#   'altern',
#   'creation',
#   'random',
#   'accord',
#   'plan',
#   'random',
#   'unabl',
#   'accept',
#   'complex',
#   'natur',
#   'world',
#   'interrel',
#   'interdepend',
#   'organ',
#   'creatur',
#   'exist',
#   'left',
#   'creation',
#   'control',
#   'intellig',
#   'capabl',
#   'devis',
#   'scheme',
#   'intellig',
#   'god',
#   'prefer',
#   'creatio',
#   'nihilo',
#   'chao',
#   'cleaner',
#   'obvious',
#   'prove',
#   'come',
#   'choos',
#   'explan',
#   'feel',
#   'comfort',
#   'damon',
#   'live',
#   'choic',
#   'shalom',
#   'howard'],
#  ['titl', 'sai', 'need', 'know', 'version'],
#  ['polit',
#   'bicker',
#   'appropri',
#   'group',
#   'brad',
#   'keplei',
#   'internet',
#   'keplei',
#   'photon',
#   'phy',
#   'unca',
#   'edu',
#   'work',
#   'dai',
#   'voic'],
#  ['exactli',
#   'observ',
#   'chip',
#   'standard',
#   'algorithm',
#   'remain',
#   'secret',
#   'leav',
#   'govern',
#   'remain',
#   'option',
#   'escrow',
#   'kei',
#   'illeg',
#   'begin',
#   'bother',
#   'terrorist',
#   'child',
#   'abus',
#   'govern',
#   'fond',
#   'refer',
#   'note',
#   'federalist',
#   'paper',
#   'stress',
#   'reason',
#   'right',
#   'citizen',
#   'bear',
#   'arm',
#   'defend',
#   'armi',
#   'armi',
#   'imho',
#   'primari',
#   'purpos',
#   'privat',
#   'crypto',
#   'defend',
#   'govern',
#   'terrorist',
#   'worri',
#   'gover',
#   'damag',
#   'qualiti',
#   'life',
#   'dai'],
#  ['cours',
#   'mike',
#   'ramsei',
#   'time',
#   'captain',
#   'buffalo',
#   'prior',
#   'trade',
#   'pittsburgh',
#   'current',
#   'penguin',
#   'captain',
#   'real',
#   'captain',
#   'lemieux',
#   'plai',
#   'rotat',
#   'season',
#   'mario',
#   'troi',
#   'lonei',
#   'worn',
#   'pen',
#   'jai'],
#  ['texa',
#   'corpu',
#   'christi',
#   'pick',
#   'phone',
#   'dial',
#   'phone',
#   'compani',
#   'read',
#   'number',
#   'work'],
#  ['sorri',
#   'thought',
#   'discuss',
#   'heresi',
#   'assum',
#   'heresi',
#   'meant',
#   'departur',
#   'orthodoxi',
#   'case',
#   'gener',
#   'accept',
#   'belief',
#   'import',
#   'issu',
#   'case',
#   'definit',
#   'word',
#   'creat',
#   'great',
#   'import',
#   'creation',
#   'issu',
#   'discuss',
#   'said',
#   'given',
#   'mormon',
#   'belief',
#   'disagre',
#   'mormon',
#   'belief',
#   'creation',
#   'function',
#   'organ',
#   'etern',
#   'exist',
#   'substanc',
#   'nihilo',
#   'creation',
#   'import',
#   'point',
#   'correct',
#   'interpret',
#   'bibl',
#   'mean',
#   'specif',
#   'term',
#   'crack',
#   'anti',
#   'mormon',
#   'presum',
#   'tell',
#   'mormon',
#   'believ',
#   'mormon',
#   'fact',
#   'believ',
#   'peopl',
#   'includ',
#   'christ',
#   'lucif',
#   'children',
#   'sens',
#   'creat',
#   'organ',
#   'believ',
#   'offspr',
#   'symbol',
#   'sens',
#   'appli',
#   'spiritu',
#   'born',
#   'word',
#   'convei',
#   'differ',
#   'mean',
#   'languag',
#   'work',
#   'robert',
#   'make',
#   'offend',
#   'word',
#   'danger',
#   'contrari',
#   'robert',
#   'her',
#   'reli',
#   'wholli',
#   'bibl',
#   'agre',
#   'sai',
#   'simpli',
#   'look',
#   'bibl',
#   'teach',
#   'centuri',
#   'peopl',
#   'shown',
#   'sure',
#   'sai',
#   'believ',
#   'understand',
#   'scriptur',
#   'clarifi',
#   'time',
#   'refer',
#   'mormon',
#   'belief',
#   'jesu',
#   'need',
#   'save',
#   'mcconki',
#   'belief',
#   'try',
#   'point',
#   'bruce',
#   'mcconki',
#   'sourc',
#   'mormon',
#   'doctrin',
#   'ignor',
#   'contrari',
#   'robert',
#   'quot',
#   'mcconki',
#   'word',
#   'mormon',
#   'canon',
#   'question',
#   'canon',
#   'great',
#   'import',
#   'fact',
#   'indic',
#   'gener',
#   'mormon',
#   'belief',
#   'ascertain',
#   'interview',
#   'larg',
#   'number',
#   'mormon'],
#  ['like',
#   'info',
#   'wavelength',
#   'think',
#   'primarili',
#   'go',
#   'bit',
#   'bit',
#   'usual',
#   'wai',
#   'common',
#   'seen',
#   'heard',
#   'sure',
#   'great',
#   'deal',
#   'differ',
#   'suggest',
#   'brand',
#   'us',
#   'remot',
#   'look',
#   'sam',
#   'photofact',
#   'detail',
#   'schemat',
#   'part',
#   'list',
#   'receiv',
#   'transmitt',
#   'includ',
#   'carrier',
#   'freq',
#   'spec',
#   'tone',
#   'decod',
#   'spec',
#   'us'],
#  ['shot',
#   'know',
#   'bought',
#   'real',
#   'cheap',
#   'equal',
#   'power',
#   'tape',
#   'player',
#   'motel',
#   'room',
#   'truckload',
#   'sale',
#   'sound',
#   'great',
#   'channel',
#   'quit',
#   'entir',
#   'open',
#   'amplifi',
#   'chip',
#   'channel',
#   'simpli',
#   'melt',
#   'solder',
#   'joint',
#   'attach',
#   'pcb',
#   'solder',
#   'work',
#   'fine',
#   'volum',
#   'lower',
#   'probabl',
#   'lousi',
#   'heat',
#   'sink',
#   'said',
#   'nice',
#   'alpin',
#   'sure',
#   'order',
#   'higher',
#   'qualiti',
#   'point',
#   'look',
#   'insid',
#   'scrap',
#   'occasion',
#   'repair',
#   'mayb',
#   'thing'],
#  ['like',
#   'veto',
#   'proof',
#   'major',
#   'hous',
#   'senat',
#   'unfortun',
#   'differ',
#   'stori',
#   'gov',
#   'vow',
#   'vote',
#   'power',
#   'addit',
#   'senat',
#   'smaller',
#   'readili',
#   'manipul',
#   'bodi',
#   'ther',
#   'hand',
#   'semi',
#   'automat',
#   'like',
#   'live',
#   'fifti',
#   'cent',
#   'hous',
#   'current',
#   'oppos',
#   'order',
#   'senat',
#   'believ',
#   'address',
#   'thought',
#   'polit',
#   'scienc',
#   'class',
#   'wast',
#   'time'],
#  ['trust',
#   'princ',
#   'biblic',
#   'proverb',
#   'modern',
#   'analog',
#   'govern',
#   'time',
#   'found',
#   'idea',
#   'citizen',
#   'right',
#   'govern',
#   'common',
#   'explicit',
#   'write',
#   'founder',
#   'consider',
#   'extent',
#   'englishmen',
#   'right',
#   'ye',
#   'time',
#   'chang',
#   'technolog',
#   'chang',
#   'possibl',
#   'govern',
#   'enserf',
#   'mankind',
#   'possibl',
#   'recent',
#   'feudal',
#   'lord',
#   'restrict',
#   'serf',
#   'peopl',
#   'enserf',
#   'better',
#   'feudal',
#   'lord',
#   'slaveown',
#   'mistreat',
#   'freedom',
#   'speech',
#   'freedom',
#   'religion',
#   'real',
#   'attack'],
#  ['promis',
#   'panther',
#   'presid',
#   'huizenga',
#   'announc',
#   'team',
#   'announc',
#   'torrei',
#   'name',
#   'presid',
#   'panther',
#   'littl',
#   'sun',
#   'sentinel',
#   'torrei',
#   'architect',
#   'consecut',
#   'stanlei',
#   'champion',
#   'persid',
#   'gener',
#   'manag',
#   'york',
#   'island',
#   'year',
#   'nhl',
#   'torrei',
#   'ti',
#   'signatur',
#   'andr',
#   'agassi',
#   'hair',
#   'panther',
#   'introduc',
#   'uniform',
#   'insignia',
#   'ticket',
#   'price',
#   'inform',
#   'earli',
#   'month',
#   'meantim',
#   'huizenga',
#   'leav',
#   'dai',
#   'dai',
#   'oper',
#   'hand',
#   'torrei',
#   'clark',
#   'florida',
#   'panther',
#   'chosen',
#   'south',
#   'florida',
#   'team',
#   'focu',
#   'attent',
#   'endang',
#   'speci',
#   'florida',
#   'panther',
#   'everglad',
#   'nation',
#   'park',
#   'cypress',
#   'nation',
#   'preserv',
#   'part',
#   'southwestern',
#   'florida',
#   'panther',
#   'quickest',
#   'strike',
#   'cat',
#   'torrei',
#   'said',
#   'hopefulli',
#   'plai',
#   'ic',
#   'bio',
#   'torrei',
#   'huizenga',
#   'hire',
#   'expans',
#   'island',
#   'respons',
#   'guid',
#   'island',
#   'consecut',
#   'stanlei',
#   'championship',
#   'season',
#   'consecut',
#   'win',
#   'season',
#   'execut',
#   'vice',
#   'presid',
#   'california',
#   'golden',
#   'seal',
#   'torrei',
#   'watch',
#   'seal',
#   'plai',
#   'off',
#   'second',
#   'season',
#   'guess',
#   'complet',
#   'person',
#   'trick',
#   'said',
#   'torrei',
#   'nativ',
#   'montreal',
#   'resid',
#   'bear',
#   'lake',
#   'countri',
#   'club',
#   'palm',
#   'beach',
#   'account',
#   'gorycki',
#   'sol',
#   'cse',
#   'fau',
#   'edu',
#   'jimg',
#   'cybernet',
#   'cse',
#   'fau',
#   'edu',
#   'repeat',
#   'stress',
#   'repeat',
#   'stress',
#   'repeat',
#   'stress',
#   'repeat',
#   'stress',
#   'repeat',
#   'adrian',
#   'belew',
#   'indiciplin'],
#  ['concept',
#   'teacher',
#   'interest',
#   'grade',
#   'curv',
#   'cheat',
#   'interest',
#   'mention',
#   'thought',
#   'provok',
#   'concept',
#   'father',
#   'children',
#   'love',
#   'love',
#   'understand',
#   'bibl',
#   'sai',
#   'look',
#   'heart',
#   'final',
#   'measur',
#   'perspect',
#   'grade',
#   'context',
#   'heart',
#   'final',
#   'test',
#   'specif',
#   'christian',
#   'agre',
#   'heaven',
#   'hell',
#   'perspect',
#   'heaven',
#   'hell',
#   'grade',
#   'pass',
#   'fail',
#   'basi',
#   'father',
#   'intervent',
#   'jesu',
#   'son',
#   'see',
#   'heart',
#   'bibl',
#   'sai',
#   'heart',
#   'know',
#   'unchang',
#   'method',
#   'make',
#   'relationship',
#   'christ',
#   'secur',
#   'uncertain',
#   'chang',
#   'landscap',
#   'yesterdai',
#   'todai',
#   'tomorrow',
#   'concern',
#   'childhood',
#   'considerd',
#   'test',
#   'convict',
#   'case',
#   'certainli',
#   'go',
#   'heaven',
#   'bibl',
#   'speak',
#   'plainli',
#   'love',
#   'care',
#   'jesu',
#   'children',
#   'realiti',
#   'children',
#   'bigger',
#   'bodi',
#   'grei',
#   'hair',
#   'father',
#   'father',
#   'like',
#   'father',
#   'want',
#   'best',
#   'mayb',
#   'deciplin',
#   'love',
#   'look',
#   'like',
#   'christian',
#   'test',
#   'make',
#   'pass',
#   'heaven',
#   'place',
#   'expert',
#   'travel',
#   'look',
#   'light',
#   'home',
#   'prai',
#   'bring'],
#  ['strike',
#   'funni',
#   'indic',
#   'crisi',
#   'economi',
#   'imagin',
#   'despar',
#   'need',
#   'market',
#   'sustain',
#   'industri',
#   'peopl',
#   'nolong',
#   'central',
#   'control',
#   'govern',
#   'rosenkranz',
#   'rosen',
#   'kranz',
#   'enet',
#   'dec',
#   'com'],
#  ['know',
#   'will',
#   'specul',
#   'peopl',
#   'suggest',
#   'chip',
#   'public',
#   'kei',
#   'cryptographi',
#   'possibl',
#   'diffi',
#   'hellman',
#   'exchang',
#   'algorithm',
#   'similar',
#   'effect',
#   'allow',
#   'end',
#   'agre',
#   'session',
#   'symmetr',
#   'cryptographi',
#   'like',
#   'de',
#   'encrypt',
#   'door',
#   'kei',
#   'work',
#   'possibl',
#   'like',
#   'algorithm',
#   'properti',
#   'session',
#   'deduc',
#   'eavesdropp',
#   'know',
#   'door',
#   'kei',
#   'possibl',
#   'communic',
#   'random',
#   'number',
#   'seed',
#   'door',
#   'kei',
#   'possibl',
#   'suggest',
#   'earlier',
#   'chip',
#   'simpli',
#   'broadcast',
#   'session',
#   'kei',
#   'encrypt',
#   'chip',
#   'intern',
#   'secret',
#   'kei',
#   'door',
#   'kei',
#   'secret',
#   'kei',
#   'usabl',
#   'decrypt',
#   'session',
#   'broadcast',
#   'actual',
#   'chip',
#   'secret',
#   'need',
#   'public',
#   'usag',
#   'ident',
#   'secret',
#   'door',
#   'kei',
#   'propos',
#   'straightforward',
#   'possibl',
#   'encrypt',
#   'algorithm',
#   'messag',
#   'dual',
#   'kei',
#   'properti',
#   'possess',
#   'kei',
#   'decrypt',
#   'session',
#   'exchang',
#   'door',
#   'chip',
#   'worth',
#   'note',
#   'propos',
#   'dorothi',
#   'den',
#   'rais',
#   'amazingli',
#   'prescient',
#   'line',
#   'discuss',
#   'novemb',
#   'decemb',
#   'variat',
#   'diffi',
#   'hellman',
#   'parti',
#   'particip',
#   'deriv',
#   'session',
#   'kei',
#   'know',
#   'clipper',
#   'work',
#   'hint',
#   'earli',
#   'knowledg',
#   'clipper',
#   'think',
#   'synchron',
#   'clipper',
#   'design',
#   'diffi',
#   'hellman',
#   'mind'],
#  ['game',
#   'adirondack',
#   'adirondack',
#   'lead',
#   'seri',
#   'round',
#   'springfield',
#   'indian',
#   'provid',
#   'bruin',
#   'springfield',
#   'provid',
#   'springfield',
#   'provid',
#   'provid',
#   'springfield',
#   'provid',
#   'springfield',
#   'springfield',
#   'provid',
#   'provid',
#   'springfield',
#   'springfield',
#   'provid',
#   'island',
#   'adirondack',
#   'wing',
#   'adirondack',
#   'adirondack',
#   'adirondack',
#   'adirondack',
#   'adirondack',
#   'adirondack',
#   'adirondack',
#   'baltimor',
#   'skipjack',
#   'binghamton',
#   'ranger',
#   'baltimor',
#   'binghamton',
#   'baltimor',
#   'binghamton',
#   'binghamton',
#   'baltimor',
#   'binghamton',
#   'baltimor',
#   'baltimor',
#   'binghamton',
#   'binghmaton',
#   'baltimor',
#   'baltimor',
#   'binghamton',
#   'utica',
#   'devil',
#   'rochest',
#   'american',
#   'utica',
#   'rochest',
#   'utica',
#   'rochest',
#   'rochest',
#   'utica',
#   'rochest',
#   'utica',
#   'utica',
#   'rochest',
#   'rochest',
#   'utica',
#   'utica',
#   'rochest',
#   'moncton',
#   'hawk',
#   'john',
#   'mapl',
#   'leaf',
#   'john',
#   'moncton',
#   'moncton',
#   'john',
#   'halifax',
#   'john',
#   'moncton',
#   'john',
#   'moncton',
#   'moncton',
#   'john',
#   'halifax',
#   'john',
#   'moncton',
#   'moncton',
#   'john',
#   'halifax',
#   'cape',
#   'breton',
#   'oiler',
#   'fredericton',
#   'canadien',
#   'fredericton',
#   'cape',
#   'breton',
#   'cape',
#   'breton',
#   'fredericton',
#   'fredericton',
#   'cape',
#   'breton',
#   'fredericton',
#   'cape',
#   'breton',
#   'cape',
#   'breton',
#   'fredericton',
#   'fredericton',
#   'cape',
#   'breton',
#   'cape',
#   'breton',
#   'fredericton'],
#  ['ye',
#   'coast',
#   'portland',
#   'nice',
#   'wai',
#   'sure',
#   'better',
#   'wai',
#   'watch',
#   'weather',
#   'good',
#   'drench',
#   'possibl',
#   'oregon',
#   'coast',
#   'rang'],
#  ['clipper',
#   'come',
#   'cellular',
#   'phone',
#   'legal',
#   'proscript',
#   'cipher',
#   'system',
#   'phone',
#   'potenti',
#   'danger',
#   'class',
#   'crime',
#   'creat',
#   'asid',
#   'possess',
#   'terrorist',
#   'tool',
#   'unapprov',
#   'encrypt',
#   'devic',
#   'program',
#   'crimin',
#   'badli',
#   'want',
#   'inscrut',
#   'tactic',
#   'commun',
#   'specif',
#   'terrorist',
#   'drug',
#   'dealer',
#   'propon',
#   'escrow',
#   'cite',
#   'threat',
#   'highli',
#   'motiv',
#   'steal',
#   'cipher',
#   'phone',
#   'legitim',
#   'user',
#   'kill',
#   'person',
#   'hold',
#   'hostag',
#   'discoveri',
#   'compromis',
#   'devic',
#   'delai',
#   'suitabl',
#   'collect',
#   'devic',
#   'stolen',
#   'crimin',
#   'commun',
#   'impun',
#   'assum',
#   'cipher',
#   'carri',
#   'trapdoor',
#   'apart',
#   'kei',
#   'escrow',
#   'compromis',
#   'discov',
#   'mean',
#   'life',
#   'cheap',
#   'crimin',
#   'current',
#   'will',
#   'kill',
#   'peopl',
#   'steal',
#   'larg',
#   'conspicu',
#   'properti',
#   'luxuri',
#   'car',
#   'reason',
#   'assum',
#   'will',
#   'kill',
#   'peopl',
#   'steal',
#   'small',
#   'inconspicu',
#   'properti',
#   'cipher',
#   'cellular',
#   'phone',
#   'seen',
#   'past',
#   'blue',
#   'box',
#   'technolog',
#   'present',
#   'modifi',
#   'cellular',
#   'phone',
#   'expect',
#   'high',
#   'stake',
#   'crimin',
#   'lucr',
#   'market',
#   'stolen',
#   'cipher',
#   'phone',
#   'dai',
#   'high',
#   'stake',
#   'crimin',
#   'life',
#   'cheap',
#   'type',
#   'substanti',
#   'amount',
#   'stolen',
#   'instrument',
#   'person',
#   'typic',
#   'discov',
#   'miss',
#   'dead',
#   'dai',
#   'stolen',
#   'instrument',
#   'usabl',
#   'dai',
#   'continu',
#   'demand',
#   'fresh',
#   'phone',
#   'fresh',
#   'bodi',
#   'clinton',
#   'go',
#   'bore',
#   'deni',
#   'unconnect',
#   'citizen',
#   'mean',
#   'defend',
#   'protect',
#   'good',
#   'pervert',
#   'trash',
#   'second',
#   'amend',
#   'target',
#   'individu',
#   'guarante',
#   'easi',
#   'prei',
#   'bodi',
#   'compar',
#   'greater',
#   'good',
#   'abl',
#   'defeat',
#   'citizen',
#   'secur',
#   'impun',
#   'think',
#   'exist',
#   'mean',
#   'usual',
#   'eavesdrop',
#   'scan',
#   'keyword',
#   'court',
#   'order',
#   'kei',
#   'great',
#   'florida',
#   'real',
#   'estat',
#   'interest',
#   'idea',
#   'escrow',
#   'kei',
#   'meant',
#   'divert',
#   'discuss',
#   'safeguard',
#   'awai',
#   'basic',
#   'fact',
#   'govern',
#   'systemat',
#   'take',
#   'awai',
#   'right',
#   'privaci',
#   'secur',
#   'mean',
#   'self',
#   'defens',
#   'right',
#   'spell',
#   'right',
#   'nawwww',
#   'govern',
#   'trust',
#   'word',
#   'clipper',
#   'similar',
#   'system',
#   'potenti',
#   'turn',
#   'current',
#   'inconveni',
#   'enforc',
#   'direct',
#   'viciou',
#   'persist',
#   'threat',
#   'gener',
#   'public',
#   'import',
#   'govern',
#   'enforc',
#   'peopl',
#   'control',
#   'safeti',
#   'gener',
#   'public',
#   'control',
#   'issu',
#   'answer',
#   'look',
#   'good',
#   'work',
#   'make',
#   'citi',
#   'safer',
#   'place',
#   'worst',
#   'regard',
#   'place',
#   'best',
#   'control',
#   'govern',
#   'public',
#   'good',
#   'control',
#   'forget',
#   'found',
#   'father',
#   'sure',
#   'concern',
#   'remaind',
#   'delet'],
#  ['doubt',
#   'quadra',
#   'specif',
#   'problem',
#   'vener',
#   'bernoulli',
#   'year',
#   'cartridg',
#   'purchas',
#   'thing',
#   'worth',
#   'tech',
#   'support',
#   'gui',
#   'ocean',
#   'microsystem',
#   'suggest',
#   'parti',
#   'driver',
#   'problem',
#   'case',
#   'cartridg',
#   'format',
#   'mount',
#   'partit'],
#  ['terri',
#   'recent',
#   'bought',
#   'lciii',
#   'datadesk',
#   'rememb',
#   'try',
#   'rebuild',
#   'desktop',
#   'strang',
#   'problem',
#   'held',
#   'shift',
#   'startup',
#   'disabl',
#   'extens',
#   'happen',
#   'tri',
#   'keyboard',
#   'connector',
#   'cabl',
#   'work',
#   'keyboard',
#   'shift',
#   'datadesk',
#   'keyboard',
#   'work',
#   'check',
#   'dipswitch',
#   'fine',
#   'disabl',
#   'extens',
#   'tell',
#   'work',
#   'annoi',
#   'datadesk',
#   'sent',
#   'keyboard',
#   'mail',
#   'inspect',
#   'repair',
#   'replac',
#   'technician',
#   'phone',
#   'said',
#   'turn',
#   'time',
#   'mean',
#   'receiv',
#   'inspect',
#   'repair',
#   'keyboard',
#   'time',
#   'keyboard',
#   'week',
#   'gotten',
#   'littl',
#   'info',
#   'annoi',
#   'cost',
#   'send',
#   'keyboard',
#   'refund',
#   'monei',
#   'costum',
#   'servic',
#   'line',
#   'toll',
#   'call',
#   'tell',
#   'similar',
#   'experi',
#   'david'],
#  ['gift',
#   'god',
#   'think',
#   'basic',
#   'reason',
#   'tradit',
#   'church',
#   'held',
#   'mari',
#   'jesu',
#   'tenet',
#   'faith',
#   'develop',
#   'particularli',
#   'augustin',
#   'equat',
#   'sex',
#   'mari',
#   'assum',
#   'virgin',
#   'life',
#   'sin',
#   'spous',
#   'god',
#   'notion',
#   'origin',
#   'sin',
#   'born',
#   'predisposit',
#   'sin',
#   'mari',
#   'predisposit',
#   'sin',
#   'origin',
#   'sin',
#   'scienc',
#   'discov',
#   'process',
#   'concept',
#   'step',
#   'assum',
#   'mari',
#   'conceiv',
#   'origin',
#   'sin',
#   'immacul',
#   'concept',
#   'mari',
#   'time',
#   'appear',
#   'girl',
#   'name',
#   'bernadett',
#   'lourd',
#   'refer',
#   'immacul',
#   'concept',
#   'year',
#   'know',
#   'doctrin',
#   'apparit',
#   'deem',
#   'true',
#   'seal',
#   'case',
#   'doctrin',
#   'hold',
#   'revel',
#   'come',
#   'equal',
#   'import',
#   'sourc',
#   'sacr',
#   'scriptur',
#   'holi',
#   'tradit',
#   'case',
#   'tradit'],
#  ['answer',
#   'dorin',
#   'question',
#   'address',
#   'specif',
#   'feel',
#   'concern',
#   'thread',
#   'southern',
#   'lebanes',
#   'villag',
#   'receiv',
#   'israel',
#   'bomb',
#   'place',
#   'death',
#   'soldier',
#   'patrol',
#   'occupi',
#   'lebanes',
#   'terrritori',
#   'terror',
#   'murder',
#   'disingen',
#   'compar',
#   'death',
#   'athlet',
#   'munich',
#   'terror',
#   'mrder',
#   'exercis',
#   'aim',
#   'sole',
#   'divert',
#   'issu',
#   'truth',
#   'dorin',
#   'remot',
#   'ignor',
#   'problem',
#   'ground',
#   'comment',
#   'charactr',
#   'irrelev',
#   'heavili',
#   'color',
#   'preconcept',
#   'misinform',
#   'paint',
#   'accur',
#   'pictur',
#   'situat',
#   'south',
#   'lebanon',
#   'home',
#   'villag',
#   'summer',
#   'inform',
#   'peopl',
#   'bunch',
#   'indiscrimin',
#   'terrorist',
#   'peopl',
#   'villag',
#   'regular',
#   'inhabit',
#   'daili',
#   'busi',
#   'work',
#   'field',
#   'small',
#   'shop',
#   'older',
#   'coff',
#   'shop',
#   'drink',
#   'coffe',
#   'hard',
#   'imagin',
#   'terrorist',
#   'camp',
#   'isra',
#   'like',
#   'view',
#   'villag',
#   'small',
#   'commun',
#   'kid',
#   'plai',
#   'soccer',
#   'street',
#   'women',
#   'prepar',
#   'lunch',
#   'plai',
#   'card',
#   'young',
#   'men',
#   'usual',
#   'ag',
#   'year',
#   'member',
#   'lebanes',
#   'resist',
#   'inhabit',
#   'villag',
#   'know',
#   'secret',
#   'peopl',
#   'suspect',
#   'young',
#   'support',
#   'financi',
#   'iran',
#   'time',
#   'sneak',
#   'arm',
#   'ammunit',
#   'occupi',
#   'zone',
#   'boobi',
#   'trap',
#   'isra',
#   'patrol',
#   'time',
#   'isra',
#   'soldier',
#   'kill',
#   'injur',
#   'trap',
#   'israel',
#   'retalli',
#   'indiscrimin',
#   'bomb',
#   'villag',
#   'choos',
#   'kill',
#   'innoc',
#   'civilian',
#   'announc',
#   'bomb',
#   'terrorist',
#   'hideout',
#   'year',
#   'girl',
#   'happen',
#   'accustom',
#   'isra',
#   'tactic',
#   'figur',
#   'isra',
#   'tell',
#   'gonna',
#   'hurt',
#   'soldier',
#   'gonna',
#   'price',
#   'accept',
#   'price',
#   'free',
#   'land',
#   'israel',
#   'know',
#   'hurt',
#   'resist',
#   'militarili',
#   'strike',
#   'keep',
#   'pressur',
#   'villag',
#   'demand',
#   'young',
#   'stop',
#   'attack',
#   'isra',
#   'soldier',
#   'attack',
#   'take',
#   'heavi',
#   'toll',
#   'live',
#   'civilian',
#   'villag',
#   'israel',
#   'retalli',
#   'polici',
#   'cold',
#   'heart',
#   'realiti',
#   'come',
#   'accept',
#   'deal',
#   'lebanes',
#   'resist',
#   'hand',
#   'go',
#   'stop',
#   'attack',
#   'occupi',
#   'isra',
#   'soldier',
#   'withdraw',
#   'real',
#   'leverag',
#   'forc',
#   'israel',
#   'withdraw',
#   'peopl',
#   'south',
#   'lebanon',
#   'occupi',
#   'shell',
#   'israel',
#   'regular',
#   'basi',
#   'want',
#   'occupi',
#   'israel',
#   'insist',
#   'call',
#   'secur',
#   'zone',
#   'necessari',
#   'protect',
#   'northern',
#   'israel',
#   'price',
#   'occup',
#   'blood',
#   'soldier',
#   'israel',
#   'interest',
#   'peac',
#   'withdraw',
#   'land',
#   'ask',
#   'establish',
#   'lebanes',
#   'occupi',
#   'zone',
#   'northern',
#   'israel',
#   'protect',
#   'villag',
#   'attack',
#   'regular',
#   'basi',
#   'israel',
#   'best',
#   'polici',
#   'remov',
#   'isra',
#   'occup',
#   'establish',
#   'peac',
#   'keep',
#   'troop',
#   'border',
#   'written',
#   'newsgroup',
#   'real',
#   'solut',
#   'come',
#   'result',
#   'comprehens',
#   'peac',
#   'settlement',
#   'israel',
#   'withdraw',
#   'border',
#   'peac',
#   'keep',
#   'troop',
#   'station',
#   'border',
#   'insur',
#   'border',
#   'shell',
#   'realist',
#   'solut',
#   'time',
#   'israel',
#   'realiz',
#   'concept',
#   'buffer',
#   'zone',
#   'aim',
#   'protect',
#   'northern',
#   'citi',
#   'fail',
#   'fact',
#   'caus',
#   'isra',
#   'death',
#   'occasion',
#   'shell',
#   'northern',
#   'israel',
#   'result',
#   'israel',
#   'want',
#   'save',
#   'isra',
#   'live',
#   'withdraw',
#   'unilater',
#   'call',
#   'secur',
#   'zone',
#   'conclus',
#   'peac',
#   'talk',
#   'save',
#   'isra',
#   'live',
#   'advanc',
#   'peac',
#   'effort',
#   'israel',
#   'great',
#   'moral',
#   'lift',
#   'better',
#   'israel',
#   'public',
#   'imag',
#   'abroad',
#   'edg',
#   'peac',
#   'negoci',
#   'israel',
#   'rightli',
#   'claim',
#   'genuin',
#   'interest',
#   'peac',
#   'offer',
#   'import',
#   'concess',
#   'withdraw',
#   'israel',
#   'demand',
#   'hizbollah',
#   'disarm',
#   'lebanes',
#   'govern',
#   'warn',
#   'accept',
#   'attack',
#   'northern',
#   'citi',
#   'shell',
#   'occur',
#   'consid',
#   'take',
#   'buffer',
#   'zone',
#   'hold',
#   'lebanes',
#   'syrian',
#   'govern',
#   'respons',
#   'littl',
#   'incent',
#   'syrian',
#   'lebanes',
#   'goovern',
#   'allow',
#   'hizbollah',
#   'bomb',
#   'israel',
#   'proper',
#   'circumst',
#   'lebanes',
#   'govern',
#   'proven',
#   'capabl',
#   'control',
#   'disarm',
#   'militia',
#   'part',
#   'lebanon',
#   'agre',
#   'case',
#   'isar',
#   'soldier',
#   'kill',
#   'qualifi',
#   'murder',
#   'matter',
#   'feel',
#   'abl',
#   'ye',
#   'quarrel',
#   'jew',
#   'isra',
#   'civilian',
#   'real',
#   'problem',
#   'occupi',
#   'isra',
#   'soldier',
#   'brave',
#   'isra',
#   'pilot',
#   'bomb',
#   'civilian',
#   'villag',
#   'time',
#   'occupi',
#   'soldier',
#   'attack'],
#  ['think',
#   'manta',
#   'european',
#   'pretti',
#   'sure',
#   'kadett',
#   'sold',
#   'pontiac',
#   'leman',
#   'think',
#   'earli',
#   'manta'],
#  ['interest',
#   'post',
#   'lyric',
#   'think',
#   'like',
#   'lyric',
#   'approach',
#   'judgement',
#   'pharisit',
#   'evangel',
#   'fundamentalist',
#   'throw',
#   'bibl',
#   'long',
#   'hair',
#   'wear',
#   'black',
#   'leather',
#   'jacket',
#   'listen',
#   'black',
#   'sabbath',
#   'throw',
#   'usual',
#   'chin',
#   'drop',
#   'come',
#   'speechless',
#   'satan',
#   'lyric',
#   'goe',
#   'import',
#   'evil',
#   'world',
#   'battl',
#   'rock',
#   'lyric'],
#  ['alt',
#   'atheism',
#   'hope',
#   'arent',
#   'convert',
#   'disagre',
#   'particular',
#   'book',
#   'weight',
#   'actual',
#   'think',
#   'statement',
#   'correct',
#   'like',
#   'jesu',
#   'fame',
#   'attribut',
#   'death',
#   'strong',
#   'motiv',
#   'propheci',
#   'signific',
#   'think',
#   'understand',
#   'sell',
#   'donat',
#   'life',
#   'religion',
#   'wast',
#   'time'],
#  ['batteri',
#   'power',
#   'devic',
#   'like',
#   'powerbook',
#   'sensit',
#   'serial',
#   'port',
#   'weird',
#   'troubl',
#   'connect',
#   'plu',
#   'handheld',
#   'work',
#   'okai',
#   'port',
#   'run',
#   'penlit',
#   'batteri',
#   'turn',
#   'plu',
#   'accid',
#   'design',
#   'flaw',
#   'put',
#   'volt',
#   'bia',
#   'serial',
#   'port',
#   'weird',
#   'thing',
#   'work',
#   'fine',
#   'connect',
#   'printer',
#   'port',
#   'screen',
#   'connect',
#   'devic',
#   'tri',
#   'printer',
#   'port',
#   'good',
#   'luck',
#   'jami'],
#  ['lloke',
#   'prizm',
#   'todai',
#   'nice',
#   'question',
#   'salesperson',
#   'answer',
#   'theft',
#   'deterr',
#   'prizm',
#   'audio',
#   'system',
#   'work',
#   'answer',
#   'geo',
#   'lteratur',
#   'thank',
#   'advanc'],
#  ['termin',
#   'possibl',
#   'connect',
#   'intern',
#   'hard',
#   'disk',
#   'macintosh',
#   'space',
#   'iisi',
#   'came',
#   'quantum',
#   'drive',
#   'space',
#   'problem',
#   'slap',
#   'quantum',
#   'sit',
#   'shelf',
#   'concern',
#   'space',
#   'drive',
#   'quantum',
#   'quarter',
#   'height',
#   'drive',
#   'final',
#   'decid',
#   'logic',
#   'place',
#   'stack',
#   'fine',
#   'snugli',
#   'problem',
#   'heat',
#   'drive',
#   'run',
#   'month',
#   'problem',
#   'connect',
#   'drive',
#   'spare',
#   'intern',
#   'hard',
#   'disk',
#   'power',
#   'cabl',
#   'half',
#   'troubl',
#   'splice',
#   'extra',
#   'cabl',
#   'squar',
#   'motherboard',
#   'connector',
#   'hard',
#   'disk',
#   'power',
#   'connector',
#   'spare',
#   'cabl',
#   'wire',
#   'connector',
#   'good',
#   'electron',
#   'store',
#   'suggest',
#   'properli',
#   'solder',
#   'heatshrink',
#   'connect',
#   'reduc',
#   'possibl',
#   'short',
#   'connect',
#   'need',
#   'ribbon',
#   'cabl',
#   'connect',
#   'spare',
#   'hard',
#   'disk',
#   'ribbon',
#   'cabl',
#   'want',
#   'care',
#   'case',
#   'word',
#   'purchas',
#   'crimp',
#   'cabl',
#   'connector',
#   'gave',
#   'male',
#   'connector',
#   'middl',
#   'spare',
#   'cabl',
#   'cost',
#   'easili',
#   'attach',
#   'good',
#   'wood',
#   'vice',
#   'theori',
#   'crimp',
#   'connector',
#   'work',
#   'origin',
#   'cabl',
#   'damag',
#   'origin',
#   'setup',
#   'have',
#   'bother',
#   'check',
#   'note',
#   'power',
#   'consumpt',
#   'plug',
#   'work',
#   'like',
#   'charm',
#   'dai',
#   'work',
#   'care',
#   'drive',
#   'ensur',
#   'termin',
#   'resistor',
#   'drive',
#   'intact',
#   'termin',
#   'resistor',
#   'logic',
#   'split',
#   'scsi',
#   'chain',
#   'signal',
#   'termin',
#   'end',
#   'know',
#   'question'],
#  ['medlin',
#   'search',
#   'turmer',
#   'potent',
#   'lipoxygenas',
#   'inhibitor',
#   'investig',
#   'number',
#   'area',
#   'cardiolog',
#   'year',
#   'cardiothorac',
#   'surgeri',
#   'hospit',
#   'compar',
#   'effect',
#   'teaspoon',
#   'dissolv',
#   'turmer',
#   'bolu',
#   'prevent',
#   'myocardi',
#   'reperfus',
#   'injuri',
#   'perfus',
#   'langendorff',
#   'sheep',
#   'heart',
#   'turmer',
#   'effect',
#   'colleagu',
#   'school',
#   'pharmaci',
#   'kohen',
#   'paper',
#   'press',
#   'free',
#   'radic',
#   'scaveng',
#   'activ',
#   'antioxid',
#   'activ',
#   'tea',
#   'josh',
#   'backon',
#   'vm',
#   'huji'],
#  ['ask',
#   'thread',
#   'line',
#   'larg',
#   'hole',
#   'current',
#   'resistor',
#   'cool',
#   'instead',
#   'heat',
#   'design',
#   'amplifi',
#   'preferenti',
#   'amplifi',
#   'hole',
#   'current',
#   'normal',
#   'electron',
#   'current',
#   'semiconductor',
#   'materi',
#   'highest',
#   'ratio',
#   'hole',
#   'mobil',
#   'electron',
#   'mobil',
#   'quot',
#   'actual',
#   'test',
#   'sampl',
#   'estim',
#   'base',
#   'theori',
#   'limit',
#   'semiconductor',
#   'consid',
#   'insul',
#   'resistor',
#   'dielectr',
#   'piezo',
#   'electr',
#   'conductor',
#   'magnet',
#   'metal',
#   'ceram',
#   'magnetostrict',
#   'note',
#   'summar',
#   'thread',
#   'state',
#   'area',
#   'hole',
#   'detect',
#   'vacuum',
#   'hole',
#   'particl',
#   'exist',
#   'presenc',
#   'matter',
#   'previou',
#   'thread',
#   'state',
#   'hole',
#   'exist',
#   'certain',
#   'semi',
#   'conductor',
#   'question',
#   'natur',
#   'aris',
#   'hole',
#   'current',
#   'insid',
#   'semi',
#   'conductor',
#   'vanish',
#   'point',
#   'semiconductor',
#   'join',
#   'conductor',
#   'copper',
#   'want',
#   'theoret',
#   'discuss',
#   'hole',
#   'exist',
#   'insid',
#   'metal',
#   'conductor',
#   'experiment',
#   'discuss',
#   'amplifi',
#   'detect',
#   'current',
#   'exist',
#   'note',
#   'cross',
#   'post',
#   'sci',
#   'electron',
#   'electron',
#   'discuss',
#   'thanx',
#   'eric',
#   'forc',
#   'natur'],
#  ['interest',
#   'write',
#   'program',
#   'gener',
#   'sird',
#   'pictur',
#   'know',
#   'stereogram',
#   'cross',
#   'ey',
#   'pictur',
#   'know',
#   'mail',
#   'steveq',
#   'sndcrft',
#   'dialix',
#   'repli',
#   'thank',
#   'help'],
#  ['chri'],
#  ['remind',
#   'plan',
#   'andrew',
#   'confer',
#   'date',
#   'date',
#   'note',
#   'chang',
#   'submiss',
#   'extens',
#   'accept',
#   'paper',
#   'tutori',
#   'topic',
#   'convert',
#   'andrew',
#   'sourc',
#   'code',
#   'tutori',
#   'discuss',
#   'step',
#   'necessari',
#   'convert',
#   'site',
#   'extend',
#   'classc',
#   'convers',
#   'sourc',
#   'code',
#   'requir',
#   'coupl',
#   'step',
#   'convert',
#   'miss',
#   'type',
#   'inform',
#   'describ',
#   'long',
#   'remaind',
#   'spent',
#   'learn',
#   'write',
#   'object',
#   'practic',
#   'andrew',
#   'technic',
#   'confer',
#   'consortium',
#   'annual',
#   'meet',
#   'june',
#   'carnegi',
#   'mellon',
#   'univers',
#   'pittsburgh',
#   'confer',
#   'held',
#   'thursdai',
#   'fridai',
#   'june',
#   'tutori',
#   'thursdai',
#   'confer',
#   'proper',
#   'annual',
#   'meet',
#   'dinner',
#   'even',
#   'dai',
#   'confer',
#   'attende',
#   'welcom',
#   'annual',
#   'meet',
#   'consortium',
#   'member',
#   'abl',
#   'vote',
#   'year',
#   'theme',
#   'applic',
#   'construct',
#   'non',
#   'programm',
#   'effort',
#   'toolkit',
#   'aim',
#   'programm',
#   'construct',
#   'applic',
#   'excel',
#   'uim',
#   'system',
#   'built',
#   'paper',
#   'address',
#   'theme',
#   'consid',
#   'question',
#   'need',
#   'applic',
#   'construct',
#   'non',
#   'programm',
#   'avoid',
#   'program',
#   'altogeth',
#   'simpl',
#   'languag',
#   'need',
#   'suffici',
#   'creat',
#   'applic',
#   'user',
#   'abl',
#   'creat',
#   'widget',
#   'widget',
#   'applic',
#   'abl',
#   'print',
#   'particip',
#   'confer',
#   'welcom',
#   'paper',
#   'appropri',
#   'theme',
#   'aspect',
#   'andrew',
#   'user',
#   'interfac',
#   'includ',
#   'applic',
# ...
#   'footbal',
#   'team',
#   'eighti',
#   'quarter',
#   'nineti',
#   'like',
#   'winner',
#   'societi',
#   'regardless',
#   'race',
#   'gender',
#   'religi',
#   'prefer',
#   'sexual',
#   'orient',
#   'mayb',
#   'white',
#   'definit',
#   'buckey',
#   'rose',
#   'bowl',
#   'somedai'],
#  ['plai',
#   'gatewai',
#   'local',
#   'bu',
#   'machin',
#   'night',
#   'appar',
#   'window',
#   'option',
#   'bit',
#   'access',
#   'virtual',
#   'memori',
#   'perman',
#   'swap',
#   'file',
#   'disk',
#   'drive',
#   'local',
#   'interfac',
#   'expect',
#   'investig',
#   'bit',
#   'option',
#   'appear',
#   'thank',
#   'help'],
#  ['wyse', 'termin', 'emul', 'comm', 'toolbox', 'avail', 'thank'],
#  ['suppos',
#   'media',
#   'want',
#   'happen',
#   'report',
#   'job',
#   'duhhh',
#   'surpris',
#   'want',
#   'riot',
#   'amaz',
#   'carri',
#   'desir',
#   'subtl',
#   'wai',
#   'carlo'],
#  ['forgot',
#   'shamski',
#   'met',
#   'player',
#   'bat',
#   'injuri',
#   'fell',
#   'short',
#   'qualifi',
#   'injuri',
#   'platoon',
#   'swoboda',
#   'swobo',
#   'jewish'],
#  ['mean',
#   'disrespect',
#   'concern',
#   'get',
#   'wound',
#   'non',
#   'issu',
#   'knowledg',
#   'peopl',
#   'point',
#   'natur',
#   'occur',
#   'substanc',
#   'lot',
#   'food',
#   'food',
#   'manufactur',
#   'prepar',
#   'known',
#   'flavor',
#   'enhanc',
#   'wife',
#   'theori',
#   'ad',
#   'food',
#   'stimul',
#   'appetit',
#   'true',
#   'believ',
#   'reason',
#   'ad',
#   'peopl',
#   'larg',
#   'charg',
#   'appetit',
#   'know',
#   'cat',
#   'cat',
#   'advantag',
#   'resign',
#   'understand',
#   'cat',
#   'tast',
#   'whimsic',
#   'suspect',
#   'check',
#   'ingredi',
#   'commerci',
#   'food',
#   'stringent',
#   'requir',
#   'food',
#   'addit',
#   'human',
#   'stupid',
#   'idea',
#   'human',
#   'be',
#   'intellig',
#   'look',
#   'interest'],
#  ['hello', 'networld', 'look', 'mailread', 'xelm', 'andrea'],
#  ['mean',
#   'approach',
#   'articl',
#   'recent',
#   'avat',
#   'week',
#   'rememb',
#   'exact',
#   'date',
#   'recent',
#   'allen'],
#  ['new', 'steve', 'statu', 'lost', 'start', 'appreci'],
#  ['case', 'panic', 'jump', 'get', 'fact', 'straight'],
#  ['rite',
#   'like',
#   'describ',
#   'joseph',
#   'campbel',
#   'occident',
#   'mytholog',
#   'describ',
#   'level',
#   'initi',
#   'think',
#   'know',
#   'campbel',
#   'info',
#   'rememb',
#   'think',
#   'littl',
#   'eclect',
#   'bit',
#   'read',
#   'campbel',
#   'try'],
#  ['repli',
#   'geb',
#   'pitt',
#   'edu',
#   'gordon',
#   'bank',
#   'decis',
#   'bulli',
#   'get',
#   'studi',
#   'like',
#   'think',
#   'indic',
#   'patient',
#   'accept',
#   'explan',
#   'think',
#   'studi',
#   'wast',
#   'time',
#   'monei',
#   'suggest',
#   'second',
#   'opinion'],
#  ['look',
#   'game',
#   'game',
#   'mail',
#   'list',
#   'offer',
#   'thank',
#   'game',
#   'want',
#   'tell'],
#  ['chevrolet',
#   'brother',
#   'respect',
#   'racer',
#   'test',
#   'driver',
#   'buick',
#   'durant',
#   'director',
#   'kick',
#   'durant',
#   'took',
#   'chevrolet',
#   'mention',
#   'found',
#   'success',
#   'chevrolet',
#   'compani',
#   'littl',
#   'known',
#   'fact',
#   'chevrolet',
#   'actual',
#   'took',
#   'durant',
#   'charg',
#   'legal',
#   'compani',
#   'chevrolet',
#   'bui',
#   'divis',
#   'chevrolet',
#   'sloan',
#   'era',
#   'shuffl',
#   'thing',
#   'board',
#   'superior',
#   'degre',
#   'autonomi',
#   'given',
#   'chevi',
#   'divis',
#   'presum',
#   'initi',
#   'structur',
#   'look',
#   'organ',
#   'chart',
#   'sloan',
#   'book',
#   'chevi',
#   'divis',
#   'report',
#   'directli',
#   'floor',
#   'passeng',
#   'divis',
#   'cover',
#   'buick',
#   'old',
#   'cadillac',
#   'oakland',
#   'pontiac'],
#  ['free',
#   'program',
#   'call',
#   'xkernel',
#   'seth',
#   'robertson',
#   'seth',
#   'ctr',
#   'columbia',
#   'edu',
#   'take',
#   'boot',
#   'limit',
#   'kernel',
#   'allow',
#   'convert',
#   'machin',
#   'semest',
#   'speedup',
#   'enorm',
#   'appreci',
#   'faster',
#   'inch',
#   'black',
#   'white',
#   'xtermin',
#   'plai',
#   'bigger',
#   'screen',
#   'boot',
#   'matter',
#   'fact',
#   'depart',
#   'bought',
#   'sun',
#   'auction',
#   'convert',
#   'xkernel',
#   'avail',
#   'anonym',
#   'ftp',
#   'ctr',
#   'columbia',
#   'edu',
#   'xkernel',
#   'xkernel',
#   'shar',
#   'xkernel',
#   'symlink',
#   'latest',
#   'version',
#   'xkernel',
#   'note',
#   'compil',
#   'version',
#   'avail',
#   'compil',
#   'work',
#   'easi',
#   'connect',
#   'xkernel',
#   'satisfi',
#   'instal',
#   'user',
#   'abl',
#   'answer',
#   'question',
#   'feel',
#   'free',
#   'email'],
#  ['good',
#   'point',
#   'held',
#   'allow',
#   'peopl',
#   'develop',
#   'path',
#   'choos',
#   'desir',
#   'heterosexu',
#   'tend',
#   'leav',
#   'hang',
#   'sens',
#   'knowledg',
#   'inform',
#   'sexual',
#   'relationship',
#   'difficult',
#   'young',
#   'person',
#   'develop',
#   'build',
#   'posit',
#   'view',
#   'themself',
#   'constantli',
#   'told',
#   'implicitli',
#   'explicitli',
#   'wrong',
#   'immor'],
#  ['design',
#   'algorithm',
#   'secur',
#   'like',
#   'secur',
#   'idea',
#   'kei',
#   'de',
#   'resist',
#   'practic',
#   'cryptanalysi',
#   'puzzl',
#   'palac',
#   'bamford',
#   'describ',
#   'employe',
#   'turn',
#   'foreign',
#   'presum',
#   'kgb',
#   'agent',
#   'despit',
#   'secur',
#   'measur',
#   'doubt',
#   'account',
#   'firm',
#   'match',
#   'confidenti',
#   'data',
#   'subject',
#   'request',
#   'thousand',
#   'polic',
#   'organ',
#   'court',
#   'land',
#   'ye',
#   'mention',
#   'ronald',
#   'william',
#   'pelton',
#   'heh',
#   'embarrass'],
#  ['told',
#   'person',
#   'care',
#   'worri',
#   'go',
#   'start',
#   'put',
#   'health',
#   'monei',
#   'homeopathi',
#   'know',
#   'get',
#   'reason',
#   'post',
#   'place',
#   'homeopathi',
#   'britain',
#   'homeopathi',
#   'avail',
#   'nation',
#   'health',
#   'servic',
#   'homeopath',
#   'practic',
#   'true',
#   'fals',
#   'import',
#   'document',
#   'investig',
#   'homeopath',
#   'principl',
#   'read',
#   'book',
#   'homeopathi',
#   'weekend',
#   'turn',
#   'section',
#   'principl',
#   'homeopath',
#   'medicin',
#   'paragraph',
#   'inform',
#   'homeopath',
#   'feel',
#   'oblig',
#   'provid',
#   'sort',
#   'explan',
#   'author',
#   'state',
#   'pride',
#   'sort',
#   'virtu',
#   'sceptic',
#   'homeopathi',
#   'narrow',
#   'mind',
#   'bigot',
#   'homeopathi',
#   'look',
#   'like',
#   'witch',
#   'doctori'],
#  ['post',
#   'app',
#   'group',
#   'respons',
#   'try',
#   'latex',
#   'help',
#   'featur',
#   'avail',
#   'emac',
#   'window',
#   'read',
#   'need',
#   'separ',
#   'latexhlp',
#   'zip',
#   'file',
#   'vmshlp',
#   'zip',
#   'file',
#   'convert',
#   'window',
#   'help',
#   'file',
#   'gotten',
#   'command',
#   'help',
#   'work'],
#  ['like',
#   'back',
#   'instead',
#   'mind',
#   'live',
#   'usual',
#   'ignor',
#   'intoler',
#   'outsid',
#   'group',
#   'level',
#   'understand',
#   'confus',
#   'redneck',
#   'white',
#   'trash',
#   'confus',
#   'understand',
#   'substanti',
#   'overlap',
#   'set',
#   'clarifi',
#   'redneck',
#   'primarili',
#   'back',
#   'instead',
#   'mind',
#   'live',
#   'usual',
#   'somewhat',
#   'ignor',
#   'somebodi',
#   'standard',
#   'held',
#   'educ',
#   'basic',
#   'read',
#   'write',
#   'math',
#   'skill',
#   'import',
#   'eventu',
#   'vocat',
#   'note',
#   'stupid',
#   'ignor',
#   'stupid',
#   'high',
#   'percentag',
#   'group',
#   'white',
#   'trash',
#   'white',
#   'trash',
#   'stereotyp',
#   'refer',
#   'word',
#   'nigger',
#   'better',
#   'black',
#   'person',
#   'met',
#   'ad',
#   'bonu',
#   'white',
#   'trash',
#   'mean',
#   'hell',
#   'father',
#   'genuin',
#   'lazi',
#   'work',
#   'qualifi',
#   'good',
#   'dishonest',
#   'white',
#   'peopl',
#   'mean',
#   'snake',
#   'squeal',
#   'like',
#   'pig',
#   'boi',
#   'deliver',
#   'redneck',
#   'sure',
#   'hell',
#   'white',
#   'trash',
#   'white',
#   'trash',
#   'assuredli',
#   'intoler',
#   'outsid',
#   'group',
#   'level',
#   'understand',
#   'redneck'],
#  ['awar',
#   'foreign',
#   'doctor',
#   'admit',
#   'train',
#   'inelig',
#   'appli',
#   'resid',
#   'alien',
#   'statu',
#   'order',
#   'green',
#   'card',
#   'return',
#   'countri',
#   'appli',
#   'embassi',
#   'cours',
#   'problem',
#   'agre',
#   'practic',
#   'town',
#   'need',
#   'congressman',
#   'district',
#   'tack',
#   'rider',
#   'sai',
#   'allow',
#   'perman',
#   'resid',
#   'bill',
#   'congress',
#   'rider',
#   'attach',
#   'marri',
#   'citizen',
#   'common',
#   'crack',
#   'try',
#   'tell',
#   'citizen',
#   'follow',
#   'spous',
#   'phillipin',
#   'whereev',
#   'gordon',
#   'bank',
#   'njxp',
#   'skeptic',
#   'chastiti',
#   'intellect',
#   'geb',
#   'cadr',
#   'dsl',
#   'pitt',
#   'edu',
#   'shame',
#   'surrend',
#   'soon'],
#  ['glad',
#   'hear',
#   'work',
#   'export',
#   'simon',
#   'leinen',
#   'ad',
#   'imakefil',
#   'athena',
#   'version',
#   'avail',
#   'file',
#   'liasun',
#   'epfl',
#   'pub',
#   'contrib',
#   'xrpc',
#   'tar',
#   'note',
#   'suffix',
#   'need',
#   'gzip',
#   'liasun',
#   'pub',
#   'gnu',
#   'uncompress',
#   'work',
#   'send',
#   'note',
#   'happi',
#   'mail',
#   'copi',
#   'probabl',
#   'start',
#   'holidai',
#   'tomorrow',
#   'martin',
#   'janzen',
#   'janzen',
#   'mprgate',
#   'mpr',
#   'teltech',
#   'nelson',
#   'burnabi',
#   'canada'],
#  ['learn',
#   'build',
#   'deyhdrat',
#   'easili',
#   'book',
#   'hungri',
#   'hiker',
#   'guid',
#   'good',
#   'food',
#   'gretchen',
#   'mchugh',
#   'heat',
#   'sourc',
#   'watt',
#   'light',
#   'bulb',
#   'basic',
#   'vertic',
#   'wooden',
#   'ventil',
#   'hole',
#   'lot',
#   'want',
#   'flow',
#   'light',
#   'bulb',
#   'goe',
#   'wire',
#   'cake',
#   'rack',
#   'space',
#   'start',
#   'bulb',
#   'slightli',
#   'higher',
#   'cost',
#   'electr',
#   'oven',
#   'note',
#   'electr',
#   'oven',
#   'oven',
#   'set',
#   'food',
#   'dri',
#   'cooki',
#   'tin',
#   'rack',
#   'oven',
#   'oven',
#   'degre',
#   'lowest',
#   'set',
#   'oven',
#   'goe',
#   'probabl',
#   'better',
#   'stick',
#   'wooden',
#   'spoon',
#   'corner',
#   'oven',
#   'close',
#   'door',
#   'spoon',
#   'stai',
#   'open',
#   'inch',
#   'allow',
#   'airflow',
#   'leav',
#   'stuff',
#   'oven',
#   'hour',
#   'check',
#   'dri',
#   'faster',
#   'dehydr',
#   'cooki',
#   'sheet',
#   'instead',
#   'rack',
#   'turn',
#   'stuff',
#   'halfwai',
#   'want',
#   'info',
#   'mail',
#   'right',
#   'stuff',
#   'gerald',
#   'belton',
#   'ozonehol',
#   'com',
#   'slmr',
#   'miss',
#   'boss',
#   'improv'],
#  ['start',
#   'notic',
#   'thing',
#   'run',
#   'window',
#   'control',
#   'panel',
#   'time',
#   'date',
#   'clock',
#   'run',
#   'minut',
#   'like',
#   'know',
#   'leav',
#   'run',
#   'time'],
#  ['hello',
#   'troubl',
#   'tcp',
#   'onpredir',
#   'printer',
#   'redirect',
#   'program',
#   'support',
#   'window',
#   'print',
#   'manag',
#   'onpredir',
#   'simpli',
#   'wait',
#   'captur',
#   'till',
#   'window',
#   'session',
#   'printer',
#   'inact',
#   'start',
#   'print',
#   'anybodi',
#   'us',
#   'program'],
#  ['look',
#   'bui',
#   'floptic',
#   'drive',
#   'wonder',
#   'experi',
#   'peopl',
#   'drive',
#   'iomega',
#   'pli',
#   'mass',
#   'microsystem',
#   'procom',
#   'main',
#   'drive',
#   'market',
#   'advic',
#   'heard',
#   'articl',
#   'macworld',
#   'sep',
#   'think',
#   'floptic',
#   'post',
#   'summari',
#   'thank',
#   'advanc',
#   'repli',
#   'post',
#   'email',
#   'whichev',
#   'prefer',
#   'nizam'],
#  ['religi',
#   'opinion',
#   'quotat',
#   'bibl',
#   'cathol',
#   'theologian',
#   'papal',
#   'bull',
#   'introduc',
#   'smilei',
#   'funni',
#   'notabl',
#   'except',
#   'subject',
#   'header',
#   'dick',
#   'instrument',
#   'redempt',
#   'post',
#   'vehicl',
#   'religi',
#   'text',
#   'literari',
#   'moral',
#   'analysi',
#   'surpris',
#   'sadden',
#   'expect',
#   'kind',
#   'behavior',
#   'evangel',
#   'born',
#   'gospel',
#   'thump',
#   'face',
#   'true',
#   'christian',
#   'protest',
#   'thought',
#   'cathol',
#   'behav',
#   'better',
#   'friend',
#   'denni',
#   'urg',
#   'follow',
#   'exampl',
#   'fellow',
#   'cathol',
#   'count',
#   'dozen',
#   'friend',
#   'practic',
#   'faith',
#   'good',
#   'exampl',
#   'decent',
#   'live',
#   'respect',
#   'common',
#   'human',
#   'stoop',
#   'level',
#   'protest',
#   'think',
#   'best',
#   'wit',
#   'strident',
#   'intrus',
#   'loud',
#   'insult',
#   'overbearingli',
#   'self',
#   'righteou',
#   'imageri',
#   'song',
#   'solomon',
#   'littl',
#   'date',
#   'middl',
#   'east',
#   'date',
#   'palm',
#   'mind',
#   'appar',
#   'accept',
#   'steami',
#   'level',
#   'accept',
#   'canon',
#   'fact',
#   'deriv',
#   'erotica',
#   'incompat',
#   'cathol',
#   'doctrin',
#   'thing',
#   'cathol',
#   'erotica',
#   'necessarili',
#   'love',
#   'stori',
#   'peopl',
#   'faith',
#   'love',
#   'stori',
#   'exploit',
#   'seek',
#   'redempt',
#   'peni',
#   'size',
#   'pai',
#   'proper',
#   'respect',
#   'digniti',
#   'partner',
#   'erot',
#   'place',
#   'submit',
#   'darknit',
#   'seri',
#   'stori',
#   'qualifi',
#   'journal',
#   'entri',
#   'ring',
#   'guess',
#   'pornographi',
#   'increas',
#   'erotica',
#   'actual',
#   'agre',
#   'nearli',
#   'enorm',
#   'dick',
#   'shot',
#   'face',
#   'stori',
#   'crap',
#   'count',
#   'nois',
#   'make',
#   'signal',
#   'nois',
#   'ration',
#   'lower',
#   'peopl',
#   'poster',
#   'actual',
#   'write',
#   'decent',
#   'prose',
#   'write',
#   'stori',
#   'instead',
#   'overwhelm',
#   'commentari',
#   'thank'],
#  ['go', 'frenzi', 'cadwel', 'park', 'go', 'watch'],
#  ['like',
#   'remind',
#   'jewish',
#   'colleagu',
#   'stori',
#   'holocaust',
#   'includ',
#   'on',
#   'holocaust',
#   'memori',
#   'museum',
#   'eaten',
#   'paper',
#   'wait',
#   'build',
#   'muesum'],
#  ['sale',
#   'amiga',
#   'mhz',
#   'unix',
#   'compat',
#   'machin',
#   'hard',
#   'drive',
#   'ram',
#   'monitor',
#   'keyboard',
#   'esc',
#   'kei',
#   'broken',
#   'ask',
#   'price',
#   'obo',
#   'mind',
#   'ask',
#   'sell',
#   'machin',
#   'damag',
#   'keyboard',
#   'price',
#   'brand',
#   'meg',
#   'meg',
#   'floppi',
#   'like',
#   'local',
#   'reason',
#   'like',
#   'monitor',
#   'brand',
#   'mhz',
#   'floppi',
#   'run',
#   'consid',
#   'damag',
#   'probab',
#   'real',
#   'version',
#   'offer',
#   'laugh',
#   'worth',
#   'dai',
#   'tzeng'],
#  ['post',
#   'friend',
#   'contact',
#   'directli',
#   'leav',
#   'mail',
#   'forward',
#   'brand',
#   'spank',
#   'new',
#   'origin',
#   'packag',
#   'open',
#   'dayna',
#   'etherprint',
#   'connector',
#   'support',
#   'base',
#   'compliant',
#   'network',
#   'connect',
#   'localtalk',
#   'compat',
#   'printer',
#   'directli',
#   'ethernet',
#   'network',
#   'work',
#   'localtalk',
#   'compat',
#   'network',
#   'printer',
#   'laserwrit',
#   'imagewrit',
#   'person',
#   'page',
#   'printer',
#   'hewlett',
#   'packard',
#   'deskwrit',
#   'hewlett',
#   'packard',
#   'laserjet',
#   'printer',
#   'famili',
#   'qume',
#   'printer',
#   'daisi',
#   'chain',
#   'maximum',
#   'localtalk',
#   'devic',
#   'workstat',
#   'modem',
#   'printer',
#   'singl',
#   'etherprint',
#   'devic',
#   'support',
#   'appletalk',
#   'phase',
#   'phase',
#   'protocol',
#   'ship',
#   'cheap',
#   'base',
#   'world'],
#  ['look',
#   'diab',
#   'newsrc',
#   'came',
#   'nuthin',
#   'good',
#   'sourc',
#   'read',
#   'particular',
#   'interest',
#   'find',
#   'intraven',
#   'insulin',
#   'inject',
#   'hepat',
#   'vein',
#   'liver',
#   'activ',
#   'whew',
#   'wotta',
#   'mouth',
#   'smell',
#   'like',
#   'pointer',
#   'help',
#   'newsgroup',
#   'mailinglist',
#   'thank'],
#  ['virtual',
#   'mous',
#   'simul',
#   'avail',
#   'told',
#   'set',
#   'right',
#   'resourc',
#   'continu',
#   'work',
#   'run',
#   'olvwm',
#   'olwm'],
#  ['netland',
#   'anybodi',
#   'know',
#   'like',
#   'macintosh',
#   'hypercard',
#   'unix',
#   'platform',
#   'thank',
#   'advanc'],
#  ['difficulti',
#   'high',
#   'includ',
#   'long',
#   'transfer',
#   'time',
#   'radiat',
#   'damag',
#   'vanallen',
#   'belt',
#   'spacecraft',
#   'arcjet',
#   'xenon',
#   'thruster',
#   'requir',
#   'huge',
#   'amount',
#   'power',
#   'nuclear',
#   'power',
#   'sourc',
#   'messi',
#   'danger',
#   'sourc',
#   'radiat',
#   'damag',
#   'solar',
#   'arrai',
#   'sensit',
#   'radiat',
#   'heavi',
#   'attitud',
#   'control',
#   'dock',
#   'pain',
#   'solar',
#   'replac',
#   'arrai',
#   'trip',
#   'current',
#   'technolog',
#   'nuclear',
#   'power',
#   'sourc',
#   'strongli',
#   'restrict',
#   'intern',
#   'treati',
#   'refuel',
#   'high',
#   'like',
#   'xenon',
#   'requir',
#   'turn',
#   'pain',
#   'develop',
#   'autonom',
#   'rendezv',
#   'long',
#   'rang',
#   'teleoper',
#   'dock',
#   'refuel',
#   'plane',
#   'chang',
#   'deltav',
#   'requir',
#   'high',
#   'forc',
#   'continu',
#   'look',
#   'thing',
#   'suppos',
#   'bide',
#   'time',
#   'till',
#   'technolog',
#   'avail',
#   'problem',
#   'solv',
#   'imposs',
#   'principl',
#   'hard',
#   'margin',
#   'cheaper',
#   'shot',
#   'rocket',
#   'todai',
#   'random',
#   'thought',
#   'high',
#   'otv',
#   'design'],
#  ['need',
#   'upgrad',
#   'floppi',
#   'drive',
#   'parti',
#   'drive',
#   'work',
#   'rom',
#   'thank',
#   'ralph',
#   'ralph',
#   'gonzalez',
#   'scienc',
#   'rutger',
#   'univ',
#   'camden',
#   'phone',
#   'internet',
#   'rgonzal',
#   'gandalf',
#   'rutger',
#   'edu'],
#  ['follow',
#   'equip',
#   'sale',
#   'kenwood',
#   'mtr',
#   'concept',
#   'mtr',
#   'hamtron',
#   'class',
#   'continu',
#   'duti',
#   'mhz',
#   'watt',
#   'watt',
#   'price',
#   'includ',
#   'ship',
#   'insur',
#   'addit',
#   'inform',
#   'contact',
#   'address',
#   'dave'],
#  ...]

# %%
import numpy as np 

drop_news = [index for index, sentence in enumerate(tokenized_news) if len(sentence) <= 1]
news_texts = np.delete(tokenized_news, drop_news, axis=0)
print(len(news_texts))
# Out:
# 10936
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## Gensim을 이용한 토픽 모델링

# %%
from gensim import corpora

dictionary = corpora.Dictionary(news_texts)
corpus = [dictionary.doc2bow(text) for text in news_texts]

print(corpus[1])
# Out:
# [(51, 1), (52, 1), (53, 1), (54, 1), (55, 1), (56, 1), (57, 1), (58, 2), (59, 1), (60, 1), (61, 1), (62, 2), (63, 1), (64, 1), (65, 1), (66, 1), (67, 1), (68, 2), (69, 3), (70, 1), (71, 1), (72, 1), (73, 1), (74, 1), (75, 2), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1), (81, 1), (82, 2), (83, 1), (84, 1), (85, 1), (86, 1)]

# %% [markdown]
# ### 잠재 의미 분석을 위한 `LsiModel`

# %%
from gensim.models import LsiModel

lsi_model = LsiModel(corpus, num_topics=20, id2word=dictionary)
topics = lsi_model.print_topics()
topics
# Out:
# [(0,
#   '0.994*"max" + 0.069*"giz" + 0.068*"bhj" + 0.025*"qax" + 0.015*"biz" + 0.014*"nrhj" + 0.014*"bxn" + 0.012*"nui" + 0.011*"ghj" + 0.011*"zei"'),
#  (1,
#   '-0.381*"file" + -0.193*"program" + -0.169*"edu" + -0.162*"imag" + -0.130*"avail" + -0.126*"output" + -0.119*"includ" + -0.115*"inform" + -0.101*"pub" + -0.100*"time"'),
#  (2,
#   '-0.408*"file" + -0.335*"output" + -0.216*"entri" + 0.171*"peopl" + 0.153*"know" + -0.137*"onam" + -0.134*"program" + 0.131*"said" + -0.129*"printf" + -0.115*"char"'),
#  (3,
#   '-0.249*"imag" + -0.226*"edu" + 0.214*"output" + 0.165*"peopl" + 0.157*"know" + 0.155*"entri" + 0.153*"said" + -0.153*"avail" + -0.142*"jpeg" + -0.124*"pub"'),
#  (4,
#   '0.549*"wire" + 0.223*"ground" + -0.214*"jpeg" + -0.213*"file" + -0.169*"imag" + 0.164*"circuit" + 0.157*"outlet" + 0.139*"connect" + 0.129*"subject" + 0.126*"neutral"'),
#  (5,
#   '-0.400*"jpeg" + -0.345*"imag" + 0.276*"anonym" + -0.246*"wire" + 0.160*"privaci" + 0.156*"internet" + -0.151*"color" + 0.144*"post" + 0.125*"inform" + 0.123*"mail"'),
#  (6,
#   '0.460*"file" + 0.215*"wire" + -0.169*"output" + -0.158*"program" + -0.154*"edu" + 0.144*"anonym" + 0.141*"firearm" + -0.137*"widget" + 0.123*"jpeg" + -0.120*"entri"'),
#  (7,
#   '0.298*"anonym" + -0.286*"file" + 0.247*"imag" + 0.246*"jpeg" + -0.178*"widget" + 0.170*"post" + 0.166*"internet" + 0.155*"privaci" + -0.138*"control" + -0.127*"drive"'),
#  (8,
#   '0.295*"hockei" + 0.279*"team" + 0.235*"game" + 0.233*"leagu" + 0.188*"season" + 0.163*"year" + -0.136*"widget" + 0.129*"plai" + 0.128*"space" + -0.122*"anonym"'),
#  (9,
#   '-0.500*"drive" + -0.275*"disk" + -0.202*"control" + -0.185*"hard" + -0.168*"bio" + 0.158*"edu" + -0.155*"support" + -0.138*"card" + -0.134*"featur" + -0.119*"scsi"'),
#  (10,
#   '-0.480*"stephanopoulo" + -0.329*"presid" + 0.238*"drive" + 0.187*"armenian" + 0.183*"peopl" + 0.125*"disk" + -0.123*"packag" + -0.120*"go" + -0.120*"think" + 0.102*"control"'),
#  (11,
#   '-0.286*"space" + 0.266*"stephanopoulo" + -0.254*"launch" + 0.213*"drive" + 0.209*"edu" + -0.172*"satellit" + 0.123*"presid" + -0.114*"widget" + 0.113*"disk" + 0.109*"com"'),
#  (12,
#   '0.248*"edu" + -0.232*"widget" + -0.200*"jpeg" + -0.172*"window" + 0.170*"graphic" + -0.161*"convert" + 0.148*"space" + 0.147*"pub" + -0.136*"applic" + -0.133*"hockei"'),
#  (13,
#   '-0.265*"jesu" + -0.196*"atheist" + -0.189*"edu" + -0.184*"christian" + -0.165*"believ" + -0.154*"god" + -0.145*"exist" + 0.139*"launch" + 0.133*"armenian" + 0.126*"space"'),
#  (14,
#   '0.290*"space" + 0.218*"launch" + 0.175*"stephanopoulo" + -0.165*"program" + -0.162*"russian" + -0.159*"govern" + 0.153*"satellit" + -0.147*"administr" + 0.128*"jesu" + 0.123*"post"'),
#  (15,
#   '0.248*"imag" + -0.236*"com" + -0.235*"jpeg" + -0.233*"edu" + 0.224*"data" + -0.218*"launch" + -0.167*"space" + -0.164*"post" + 0.162*"graphic" + -0.146*"anonym"'),
#  (16,
#   '-0.238*"south" + -0.219*"rockefel" + -0.204*"secret" + -0.197*"island" + -0.181*"nuclear" + -0.166*"bolshevik" + 0.157*"health" + -0.153*"militari" + -0.144*"ship" + -0.134*"georgia"'),
#  (17,
#   '0.255*"anonym" + 0.222*"edu" + 0.197*"post" + -0.180*"jesu" + -0.170*"pub" + -0.153*"privaci" + 0.149*"imag" + 0.135*"health" + -0.127*"window" + -0.125*"inform"'),
#  (18,
#   '0.290*"stephanopoulo" + 0.180*"health" + -0.179*"administr" + -0.162*"govern" + -0.155*"senior" + -0.147*"offici" + -0.147*"russia" + -0.143*"fund" + -0.143*"russian" + -0.123*"think"'),
#  (19,
#   '-0.386*"turkish" + -0.315*"jew" + -0.224*"armenian" + -0.202*"jpeg" + -0.197*"turkei" + -0.154*"nazi" + 0.132*"entri" + 0.129*"imag" + -0.128*"drive" + -0.121*"edu"')]

# %%
from gensim.models.coherencemodel import CoherenceModel

min_topics, max_topics = 20 , 25
coherence_scores = []

for num_topics in range(min_topics, max_topics):
  model = LsiModel(corpus, num_topics=num_topics, id2word=dictionary)
  coherence = CoherenceModel(model=model,
                             texts=news_texts,
                             dictionary=dictionary)
  coherence_scores.append(coherence.get_coherence()) # 모델의 값이 나옴 

print(coherence_scores)
# Out:
# [0.5235852189351753, 0.5009365948652176, 0.5481911097898718, 0.484905205043883, 0.4513582666665516]

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

x = [int(i) for i in range(min_topics, max_topics)]

plt.figure(figsize=(10, 6))
plt.plot(x, coherence_scores)
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Scores')
plt.show()

# %%
lsi_model = LsiModel(corpus, num_topics=24, id2word=dictionary)
topics = lsi_model.print_topics(num_topics=24)
topics
# Out:
# [(0,
#   '0.994*"max" + 0.069*"giz" + 0.068*"bhj" + 0.025*"qax" + 0.015*"biz" + 0.014*"nrhj" + 0.014*"bxn" + 0.012*"nui" + 0.011*"ghj" + 0.011*"zei"'),
#  (1,
#   '0.381*"file" + 0.193*"program" + 0.169*"edu" + 0.162*"imag" + 0.130*"avail" + 0.126*"output" + 0.119*"includ" + 0.115*"inform" + 0.101*"pub" + 0.100*"time"'),
#  (2,
#   '0.408*"file" + 0.335*"output" + 0.216*"entri" + -0.171*"peopl" + -0.153*"know" + 0.137*"onam" + 0.134*"program" + -0.131*"said" + 0.129*"printf" + 0.115*"char"'),
#  (3,
#   '-0.249*"imag" + -0.226*"edu" + 0.214*"output" + 0.165*"peopl" + 0.157*"know" + 0.155*"entri" + 0.153*"said" + -0.153*"avail" + -0.142*"jpeg" + -0.124*"pub"'),
#  (4,
#   '-0.549*"wire" + -0.223*"ground" + 0.214*"jpeg" + 0.213*"file" + 0.169*"imag" + -0.164*"circuit" + -0.157*"outlet" + -0.139*"connect" + -0.129*"subject" + -0.126*"neutral"'),
#  (5,
#   '0.400*"jpeg" + 0.345*"imag" + -0.276*"anonym" + 0.246*"wire" + -0.160*"privaci" + -0.156*"internet" + 0.151*"color" + -0.144*"post" + -0.125*"inform" + -0.123*"mail"'),
#  (6,
#   '0.460*"file" + 0.215*"wire" + -0.169*"output" + -0.158*"program" + -0.154*"edu" + 0.144*"anonym" + 0.141*"firearm" + -0.137*"widget" + 0.123*"jpeg" + -0.120*"entri"'),
#  (7,
#   '-0.298*"anonym" + 0.286*"file" + -0.247*"imag" + -0.246*"jpeg" + 0.178*"widget" + -0.170*"post" + -0.166*"internet" + -0.155*"privaci" + 0.138*"control" + 0.127*"drive"'),
#  (8,
#   '0.295*"hockei" + 0.279*"team" + 0.235*"game" + 0.233*"leagu" + 0.188*"season" + 0.163*"year" + -0.136*"widget" + 0.129*"plai" + 0.128*"space" + -0.122*"anonym"'),
#  (9,
#   '0.500*"drive" + 0.275*"disk" + 0.202*"control" + 0.185*"hard" + 0.168*"bio" + -0.158*"edu" + 0.154*"support" + 0.138*"card" + 0.134*"featur" + 0.119*"scsi"'),
#  (10,
#   '0.480*"stephanopoulo" + 0.328*"presid" + -0.238*"drive" + -0.187*"armenian" + -0.183*"peopl" + -0.125*"disk" + 0.123*"packag" + 0.120*"go" + 0.120*"think" + -0.102*"control"'),
#  (11,
#   '0.286*"space" + -0.266*"stephanopoulo" + 0.254*"launch" + -0.213*"drive" + -0.209*"edu" + 0.172*"satellit" + -0.123*"presid" + 0.114*"widget" + -0.113*"disk" + -0.109*"com"'),
#  (12,
#   '-0.248*"edu" + 0.232*"widget" + 0.200*"jpeg" + 0.172*"window" + -0.170*"graphic" + 0.161*"convert" + -0.148*"space" + -0.147*"pub" + 0.136*"applic" + 0.133*"hockei"'),
#  (13,
#   '0.265*"jesu" + 0.196*"atheist" + 0.189*"edu" + 0.184*"christian" + 0.165*"believ" + 0.154*"god" + 0.145*"exist" + -0.140*"launch" + -0.133*"armenian" + -0.126*"space"'),
#  (14,
#   '0.290*"space" + 0.218*"launch" + 0.175*"stephanopoulo" + -0.166*"program" + -0.162*"russian" + -0.159*"govern" + 0.153*"satellit" + -0.147*"administr" + 0.128*"jesu" + 0.123*"post"'),
#  (15,
#   '0.248*"imag" + -0.236*"com" + -0.235*"jpeg" + -0.233*"edu" + 0.224*"data" + -0.218*"launch" + -0.168*"space" + -0.164*"post" + 0.162*"graphic" + -0.146*"anonym"'),
#  (16,
#   '0.238*"south" + 0.219*"rockefel" + 0.204*"secret" + 0.198*"island" + 0.182*"nuclear" + 0.166*"bolshevik" + -0.157*"health" + 0.153*"militari" + 0.143*"ship" + 0.134*"georgia"'),
#  (17,
#   '-0.255*"anonym" + -0.222*"edu" + -0.197*"post" + 0.181*"jesu" + 0.170*"pub" + 0.153*"privaci" + -0.150*"imag" + -0.135*"health" + 0.127*"window" + 0.125*"inform"'),
#  (18,
#   '-0.290*"stephanopoulo" + -0.180*"health" + 0.179*"administr" + 0.161*"govern" + 0.155*"senior" + 0.147*"offici" + 0.147*"russia" + 0.143*"fund" + 0.143*"russian" + 0.123*"think"'),
#  (19,
#   '0.386*"turkish" + 0.314*"jew" + 0.224*"armenian" + 0.202*"jpeg" + 0.197*"turkei" + 0.154*"nazi" + -0.132*"entri" + -0.129*"imag" + 0.129*"drive" + 0.121*"edu"'),
#  (20,
#   '-0.265*"turkish" + -0.230*"entri" + 0.228*"edu" + -0.218*"jew" + -0.159*"anonym" + 0.158*"jpeg" + -0.155*"imag" + -0.140*"armenian" + 0.139*"com" + -0.136*"turkei"'),
#  (21,
#   '-0.474*"entri" + 0.236*"output" + -0.169*"rule" + 0.144*"jesu" + 0.132*"anonym" + 0.125*"imag" + -0.119*"follow" + 0.119*"avail" + 0.110*"scx" + -0.107*"com"'),
#  (22,
#   '0.816*"scx" + 0.277*"gcx" + 0.183*"syx" + 0.179*"mcx" + 0.099*"gyx" + 0.098*"xxi" + 0.096*"uc" + 0.091*"bhj" + 0.091*"chz" + 0.086*"cub"'),
#  (23,
#   '-0.251*"bit" + -0.243*"scsi" + -0.207*"edu" + -0.186*"chip" + -0.180*"encrypt" + -0.175*"com" + -0.148*"turkish" + 0.144*"drive" + 0.143*"entri" + -0.140*"kei"')]

# %% [markdown]
# ### 잠재 디리클레 할당을 위한 `LdaModel`

# %%
from gensim.models import LdaModel

lda_model = LdaModel(corpus, num_topics=20, id2word=dictionary)
topics = lda_model.print_topics()
topics
# Out:
# [(0,
#   '0.009*"work" + 0.008*"scsi" + 0.006*"output" + 0.006*"like" + 0.005*"mode" + 0.005*"control" + 0.005*"time" + 0.005*"problem" + 0.005*"need" + 0.005*"data"'),
#  (1,
#   '0.017*"game" + 0.014*"team" + 0.011*"year" + 0.011*"plai" + 0.009*"player" + 0.006*"season" + 0.005*"leagu" + 0.005*"good" + 0.005*"like" + 0.005*"score"'),
#  (2,
#   '0.010*"christian" + 0.008*"peopl" + 0.006*"right" + 0.006*"exist" + 0.006*"mean" + 0.005*"moral" + 0.005*"like" + 0.005*"think" + 0.005*"jew" + 0.004*"state"'),
#  (3,
#   '0.188*"max" + 0.021*"giz" + 0.017*"bhj" + 0.014*"bxn" + 0.013*"printf" + 0.011*"output" + 0.007*"qax" + 0.005*"onam" + 0.005*"chz" + 0.005*"nrhj"'),
#  (4,
#   '0.009*"bike" + 0.008*"car" + 0.007*"ground" + 0.007*"pain" + 0.007*"like" + 0.006*"time" + 0.005*"look" + 0.005*"good" + 0.005*"mile" + 0.005*"ride"'),
#  (5,
#   '0.033*"armenian" + 0.015*"turkish" + 0.011*"greek" + 0.008*"turkei" + 0.007*"turk" + 0.007*"russian" + 0.006*"muslim" + 0.006*"nazi" + 0.006*"genocid" + 0.006*"armenia"'),
#  (6,
#   '0.007*"detector" + 0.006*"radar" + 0.005*"power" + 0.004*"allah" + 0.004*"think" + 0.004*"sydor" + 0.004*"know" + 0.003*"like" + 0.003*"good" + 0.003*"intak"'),
#  (7,
#   '0.017*"file" + 0.015*"program" + 0.014*"window" + 0.008*"entri" + 0.007*"avail" + 0.006*"softwar" + 0.006*"problem" + 0.006*"line" + 0.006*"version" + 0.005*"displai"'),
#  (8,
#   '0.016*"kei" + 0.010*"secur" + 0.008*"encrypt" + 0.008*"chip" + 0.007*"edu" + 0.007*"anonym" + 0.007*"mail" + 0.007*"clipper" + 0.006*"public" + 0.006*"ripem"'),
#  (9,
#   '0.027*"drive" + 0.019*"disk" + 0.012*"card" + 0.011*"price" + 0.008*"hard" + 0.008*"sale" + 0.007*"sell" + 0.007*"ship" + 0.007*"work" + 0.007*"floppi"'),
#  (10,
#   '0.009*"like" + 0.008*"know" + 0.007*"post" + 0.007*"juda" + 0.006*"card" + 0.006*"monitor" + 0.006*"church" + 0.005*"repli" + 0.005*"think" + 0.005*"hang"'),
#  (11,
#   '0.008*"year" + 0.006*"tobacco" + 0.004*"promo" + 0.004*"like" + 0.004*"clemen" + 0.004*"smith" + 0.004*"outbreak" + 0.004*"paid" + 0.003*"ball" + 0.003*"speaker"'),
#  (12,
#   '0.008*"peopl" + 0.008*"like" + 0.007*"know" + 0.006*"think" + 0.006*"said" + 0.006*"right" + 0.005*"believ" + 0.005*"time" + 0.005*"sai" + 0.004*"thing"'),
#  (13,
#   '0.010*"imak" + 0.006*"kent" + 0.004*"max" + 0.004*"indiana" + 0.003*"uil" + 0.003*"window" + 0.003*"edu" + 0.003*"motorola" + 0.003*"powerbook" + 0.003*"cursor"'),
#  (14,
#   '0.019*"jesu" + 0.011*"god" + 0.010*"edu" + 0.009*"book" + 0.007*"bibl" + 0.007*"christ" + 0.007*"word" + 0.006*"christian" + 0.005*"john" + 0.005*"truth"'),
#  (15,
#   '0.014*"space" + 0.007*"len" + 0.006*"orbit" + 0.005*"year" + 0.004*"time" + 0.004*"mission" + 0.004*"lunar" + 0.004*"earth" + 0.004*"like" + 0.004*"balloon"'),
#  (16,
#   '0.012*"file" + 0.008*"imag" + 0.008*"diseas" + 0.007*"edu" + 0.007*"medic" + 0.006*"mail" + 0.006*"jpeg" + 0.006*"health" + 0.005*"patient" + 0.005*"inform"'),
#  (17,
#   '0.011*"obfusc" + 0.008*"col" + 0.007*"smokeless" + 0.006*"nasa" + 0.005*"center" + 0.005*"program" + 0.004*"edu" + 0.004*"year" + 0.004*"null" + 0.003*"row"'),
#  (18,
#   '0.009*"israel" + 0.007*"space" + 0.006*"arab" + 0.005*"launch" + 0.005*"time" + 0.004*"jew" + 0.004*"satellit" + 0.004*"palestinian" + 0.004*"year" + 0.004*"isra"'),
#  (19,
#   '0.014*"peopl" + 0.009*"think" + 0.008*"know" + 0.007*"time" + 0.006*"govern" + 0.005*"like" + 0.005*"state" + 0.005*"want" + 0.005*"thing" + 0.005*"work"')]

# %%
from gensim.models.coherencemodel import CoherenceModel

min_topics, max_topics = 20 , 25
coherence_scores = []

for num_topics in range(min_topics, max_topics):
  model = LdaModel(corpus, num_topics=num_topics, id2word=dictionary)
  coherence = CoherenceModel(model=model,
                             texts=news_texts,
                             dictionary=dictionary)
  coherence_scores.append(coherence.get_coherence()) # 모델의 값이 나옴 

print(coherence_scores)
# Out:
# [0.5021609820979924, 0.5361591874517606, 0.48456224890076255, 0.5204935365660042, 0.5441953787037007]

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

x = [int(i) for i in range(min_topics, max_topics)]

plt.figure(figsize=(10, 6))
plt.plot(x, coherence_scores)
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Scores')
plt.show()

# %%
lda_model = LdaModel(corpus, num_topics=22, id2word=dictionary)
topics = lda_model.print_topics(num_topics=22)
topics
# Out:
# [(0,
#   '0.016*"obfusc" + 0.009*"edu" + 0.005*"toni" + 0.005*"glutam" + 0.005*"com" + 0.004*"invad" + 0.004*"msg" + 0.003*"mail" + 0.003*"fuse" + 0.002*"armenian"'),
#  (1,
#   '0.005*"univers" + 0.005*"file" + 0.005*"think" + 0.004*"speaker" + 0.004*"professor" + 0.004*"thing" + 0.004*"good" + 0.004*"exist" + 0.003*"peopl" + 0.003*"mean"'),
#  (2,
#   '0.037*"max" + 0.024*"drive" + 0.014*"disk" + 0.008*"card" + 0.008*"hard" + 0.007*"color" + 0.006*"like" + 0.006*"tape" + 0.006*"floppi" + 0.005*"cabl"'),
#  (3,
#   '0.025*"game" + 0.020*"team" + 0.016*"year" + 0.014*"plai" + 0.012*"player" + 0.009*"season" + 0.007*"good" + 0.007*"hockei" + 0.007*"leagu" + 0.006*"score"'),
#  (4,
#   '0.011*"chip" + 0.010*"kei" + 0.009*"encrypt" + 0.007*"govern" + 0.007*"secur" + 0.007*"clipper" + 0.006*"technolog" + 0.005*"phone" + 0.005*"year" + 0.005*"work"'),
#  (5,
#   '0.012*"com" + 0.011*"edu" + 0.005*"inform" + 0.005*"april" + 0.005*"filenam" + 0.004*"univers" + 0.004*"center" + 0.004*"includ" + 0.004*"state" + 0.004*"address"'),
#  (6,
#   '0.009*"period" + 0.009*"ground" + 0.007*"wire" + 0.007*"edu" + 0.006*"power" + 0.005*"pitt" + 0.005*"scorer" + 0.005*"chz" + 0.004*"outlet" + 0.004*"gordon"'),
#  (7,
#   '0.021*"window" + 0.012*"problem" + 0.011*"thank" + 0.011*"program" + 0.011*"work" + 0.010*"file" + 0.008*"softwar" + 0.008*"need" + 0.008*"version" + 0.008*"know"'),
#  (8,
#   '0.008*"book" + 0.007*"like" + 0.006*"work" + 0.006*"know" + 0.006*"myer" + 0.005*"time" + 0.004*"look" + 0.004*"problem" + 0.004*"want" + 0.003*"kent"'),
#  (9,
#   '0.018*"israel" + 0.013*"isra" + 0.012*"jew" + 0.011*"arab" + 0.007*"palestinian" + 0.006*"right" + 0.006*"nazi" + 0.006*"attack" + 0.006*"peopl" + 0.005*"kill"'),
#  (10,
#   '0.014*"jesu" + 0.010*"christian" + 0.010*"god" + 0.009*"believ" + 0.007*"religion" + 0.007*"know" + 0.006*"life" + 0.006*"time" + 0.006*"bibl" + 0.006*"peopl"'),
#  (11,
#   '0.008*"think" + 0.008*"like" + 0.007*"moral" + 0.006*"object" + 0.006*"peopl" + 0.006*"differ" + 0.005*"case" + 0.005*"year" + 0.004*"rule" + 0.004*"problem"'),
#  (12,
#   '0.011*"christian" + 0.008*"word" + 0.007*"think" + 0.007*"peopl" + 0.006*"mean" + 0.006*"exist" + 0.005*"argument" + 0.005*"true" + 0.005*"thing" + 0.005*"evid"'),
#  (13,
#   '0.012*"contest" + 0.008*"len" + 0.006*"water" + 0.006*"entri" + 0.006*"like" + 0.005*"rule" + 0.004*"plant" + 0.004*"file" + 0.004*"output" + 0.004*"auth"'),
#  (14,
#   '0.010*"space" + 0.008*"like" + 0.005*"look" + 0.005*"bike" + 0.005*"price" + 0.005*"time" + 0.004*"car" + 0.004*"work" + 0.004*"engin" + 0.004*"launch"'),
#  (15,
#   '0.010*"diseas" + 0.009*"health" + 0.006*"edu" + 0.006*"medic" + 0.006*"copi" + 0.006*"coli" + 0.005*"patient" + 0.005*"infect" + 0.004*"program" + 0.004*"research"'),
#  (16,
#   '0.049*"max" + 0.023*"file" + 0.014*"program" + 0.013*"entri" + 0.010*"output" + 0.008*"avail" + 0.008*"edu" + 0.007*"line" + 0.007*"window" + 0.007*"giz"'),
#  (17,
#   '0.007*"post" + 0.005*"user" + 0.005*"public" + 0.005*"inform" + 0.004*"gener" + 0.004*"mail" + 0.004*"ripem" + 0.004*"secur" + 0.004*"messag" + 0.004*"includ"'),
#  (18,
#   '0.015*"keyboard" + 0.009*"pain" + 0.008*"appl" + 0.007*"think" + 0.006*"know" + 0.005*"like" + 0.005*"monitor" + 0.005*"atheist" + 0.005*"peopl" + 0.004*"time"'),
#  (19,
#   '0.009*"gun" + 0.007*"tobacco" + 0.006*"power" + 0.005*"peopl" + 0.005*"rate" + 0.005*"state" + 0.005*"year" + 0.005*"right" + 0.005*"govern" + 0.004*"protect"'),
#  (20,
#   '0.013*"peopl" + 0.008*"armenian" + 0.007*"time" + 0.007*"said" + 0.006*"know" + 0.006*"think" + 0.006*"right" + 0.005*"state" + 0.005*"like" + 0.004*"go"'),
#  (21,
#   '0.014*"bit" + 0.012*"scsi" + 0.006*"data" + 0.006*"number" + 0.005*"chip" + 0.005*"algorithm" + 0.005*"public" + 0.004*"kei" + 0.004*"know" + 0.004*"control"')]

# %% [markdown]
# ## 토픽 모델링 시각화

# %%
# !pip install pyLDAvis
# Out:
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      |████████████████████████████████| 1.7 MB 14.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.4.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.7.3)
# Collecting numpy>=1.20.0
#   Downloading numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 199 kB/s
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Collecting funcy
#   Downloading funcy-1.16-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.1)
# Collecting pandas>=1.2.0
#   Downloading pandas-1.3.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 70.0 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.22.2.post1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (PEP 517) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136897 sha256=2672c12b5b7e71a58cc8c59333ab6e053dc0e0b3283bd298bd3c6e994332115d
#   Stored in directory: /root/.cache/pip/wheels/c9/21/f6/17bcf2667e8a68532ba2fbf6d5c72fdf4c7f7d9abfa4852d2f
# Successfully built pyLDAvis
# Installing collected packages: numpy, pandas, funcy, pyLDAvis
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.0 requires numpy~=1.19.2, but you have numpy 1.21.2 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.3 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed funcy-1.16 numpy-1.21.2 pandas-1.3.3 pyLDAvis-3.3.1

# %%
import pyLDAvis.gensim

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# /usr/local/lib/python3.7/dist-packages/past/types/oldstr.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Iterable
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-bf43c28f5ca5> in <module>()
# ----> 1 import pyLDAvis.gensim
#
# ModuleNotFoundError: No module named 'pyLDAvis.gensim'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
