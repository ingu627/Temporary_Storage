# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py): started
#   Building wheel for sgmllib3k (setup.py): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=1945211d3593a9873e28c737cf5f9fd0d64dd25cfb5158bc27213b240bf33307
#   Stored in directory: c:\users\poeun\appdata\local\pip\cache\wheels\bb\cb\26\83c0b63161dc478ded6db8d83a148d32b6cce8606043c2023b
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.8 sgmllib3k-1.0.0

# %%
# https://ingu627.github.io/feed.xml

# %%
import feedparser 
poeun_blog_rss_url = "https://ingu627.github.io/feed.xml" 
rss_feed = feedparser.parse(poeun_blog_rss_url)

# %%
rss_feed
# Out:
# {'bozo': False,
#  'entries': [{'title': 'R 기초 ~ 심화 문법 총정리 (5) - 분석 모형 구축',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': 'R 기초 ~ 심화 문법 총정리 (5) - 분석 모형 구축'},
#    'summary': '+ ADsP, 빅데이터분석기사 실기 작업형 대비 - 나이브베이즈 정리까지',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '+ ADsP, 빅데이터분석기사 실기 작업형 대비 - 나이브베이즈 정리까지'},
#    'published': 'Wed, 17 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=16, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=320, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/r/R_basic_to_pro_5/'}],
#    'link': 'https://ingu627.github.io/r/R_basic_to_pro_5/',
#    'id': 'https://ingu627.github.io/r/R_basic_to_pro_5/',
#    'guidislink': False},
#   {'title': 'R 기초 ~ 심화 문법 총정리 (4) - 분석 모형 구축',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': 'R 기초 ~ 심화 문법 총정리 (4) - 분석 모형 구축'},
#    'summary': '+ ADsP, 빅데이터분석기사 실기 작업형 대비 - 로지스틱 회귀분석까지',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '+ ADsP, 빅데이터분석기사 실기 작업형 대비 - 로지스틱 회귀분석까지'},
#    'published': 'Tue, 16 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=15, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=319, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/r/R_basic_to_pro_4/'}],
#    'link': 'https://ingu627.github.io/r/R_basic_to_pro_4/',
#    'id': 'https://ingu627.github.io/r/R_basic_to_pro_4/',
#    'guidislink': False},
#   {'title': '파이썬(python) 함수 기능 정리 - update',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '파이썬(python) 함수 기능 정리 - update'},
#    'summary': '배웠던 것들. 알고리즘 사용한 것들 (계속 업데이트)',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '배웠던 것들. 알고리즘 사용한 것들 (계속 업데이트)'},
#    'published': 'Mon, 15 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=14, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=318, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/python/python_func/'}],
#    'link': 'https://ingu627.github.io/python/python_func/',
#    'id': 'https://ingu627.github.io/python/python_func/',
#    'guidislink': False},
#   {'title': '[케라스(keras) 이해] 6장. 텍스트와 시퀀스를 위한 딥러닝 (1)',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '[케라스(keras) 이해] 6장. 텍스트와 시퀀스를 위한 딥러닝 (1)'},
#    'summary': '케라스 창시자에게 배우는 딥러닝 요약',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '케라스 창시자에게 배우는 딥러닝 요약'},
#    'published': 'Mon, 15 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=14, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=318, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/python/keras_ch6_org_1/'}],
#    'link': 'https://ingu627.github.io/python/keras_ch6_org_1/',
#    'id': 'https://ingu627.github.io/python/keras_ch6_org_1/',
#    'guidislink': False},
#   {'title': 'R 기초 ~ 심화 문법 총정리 (3) - 데이터 정제, 분석 모형 선택',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': 'R 기초 ~ 심화 문법 총정리 (3) - 데이터 정제, 분석 모형 선택'},
#    'summary': '+ ADsP, 빅데이터분석기사 실기 작업형 대비',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '+ ADsP, 빅데이터분석기사 실기 작업형 대비'},
#    'published': 'Mon, 15 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=14, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=318, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/r/R_basic_to_pro_3/'}],
#    'link': 'https://ingu627.github.io/r/R_basic_to_pro_3/',
#    'id': 'https://ingu627.github.io/r/R_basic_to_pro_3/',
#    'guidislink': False},
#   {'title': 'Bootstrap(부트스트랩) 기초 실습 (2)',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': 'Bootstrap(부트스트랩) 기초 실습 (2)'},
#    'summary': '문법 및 github 예제로 실습',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '문법 및 github 예제로 실습'},
#    'published': 'Sat, 13 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=12, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=316, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/web/bootstrap_basic_2/'}],
#    'link': 'https://ingu627.github.io/web/bootstrap_basic_2/',
#    'id': 'https://ingu627.github.io/web/bootstrap_basic_2/',
#    'guidislink': False},
#   {'title': '[에러 해결 방법] R package 설치 오류 : ~로 복사하는데 문제가 발생했습니다: Permission denied',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '[에러 해결 방법] R package 설치 오류 : ~로 복사하는데 문제가 발생했습니다: Permission denied'},
#    'summary': '<h2 id="원인--filecopysavedcopy-lib-recursive--true에서--로-복사하는데-문제가-발생했습니다-permission-denied">원인 : file.copy(savedcopy, lib, recursive = TRUE)에서 ~ 로 복사하는데 문제가 발생했습니다: Permission denied</h2>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '<h2 id="원인--filecopysavedcopy-lib-recursive--true에서--로-복사하는데-문제가-발생했습니다-permission-denied">원인 : file.copy(savedcopy, lib, recursive = TRUE)에서 ~ 로 복사하는데 문제가 발생했습니다: Permission denied</h2>'},
#    'published': 'Sat, 13 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=12, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=316, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/error/Permission_denied_R/'}],
#    'link': 'https://ingu627.github.io/error/Permission_denied_R/',
#    'id': 'https://ingu627.github.io/error/Permission_denied_R/',
#    'guidislink': False},
#   {'title': '[케라스(keras) 이해] 5장. 컴퓨터 비전을 위한 딥러닝 (5)',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '[케라스(keras) 이해] 5장. 컴퓨터 비전을 위한 딥러닝 (5)'},
#    'summary': '케라스 창시자에게 배우는 딥러닝 요약',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '케라스 창시자에게 배우는 딥러닝 요약'},
#    'published': 'Fri, 12 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=11, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=315, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/python/keras_ch5_org_5/'}],
#    'link': 'https://ingu627.github.io/python/keras_ch5_org_5/',
#    'id': 'https://ingu627.github.io/python/keras_ch5_org_5/',
#    'guidislink': False},
#   {'title': 'R 기초 ~ 심화 문법 총정리 (2) - 데이터 수집, 전처리',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': 'R 기초 ~ 심화 문법 총정리 (2) - 데이터 수집, 전처리'},
#    'summary': '+ ADsP, 빅데이터분석기사 실기 작업형 대비',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '+ ADsP, 빅데이터분석기사 실기 작업형 대비'},
#    'published': 'Fri, 12 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=11, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=315, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/r/R_basic_to_pro_2/'}],
#    'link': 'https://ingu627.github.io/r/R_basic_to_pro_2/',
#    'id': 'https://ingu627.github.io/r/R_basic_to_pro_2/',
#    'guidislink': False},
#   {'title': '[케라스(keras) 이해] 5장. 컴퓨터 비전을 위한 딥러닝 (4)',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '[케라스(keras) 이해] 5장. 컴퓨터 비전을 위한 딥러닝 (4)'},
#    'summary': '케라스 창시자에게 배우는 딥러닝 요약',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://ingu627.github.io/feed.xml',
#     'value': '케라스 창시자에게 배우는 딥러닝 요약'},
#    'published': 'Thu, 11 Nov 2021 00:00:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=10, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=314, tm_isdst=0),
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://ingu627.github.io/python/keras_ch5_org_4/'}],
#    'link': 'https://ingu627.github.io/python/keras_ch5_org_4/',
#    'id': 'https://ingu627.github.io/python/keras_ch5_org_4/',
#    'guidislink': False}],
#  'feed': {'title': 'Hyunseok Jung',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://ingu627.github.io/feed.xml',
#    'value': 'Hyunseok Jung'},
#   'subtitle': '개인 저장공간입니다.<br />도움이 되길 바랍니다.<br /> Since 21.10.29',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://ingu627.github.io/feed.xml',
#    'value': '개인 저장공간입니다.<br />도움이 되길 바랍니다.<br /> Since 21.10.29'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://ingu627.github.io'},
#    {'href': 'https://ingu627.github.io/feed.xml',
#     'rel': 'self',
#     'type': 'application/rss+xml'}],
#   'link': 'https://ingu627.github.io',
#   'updated': 'Wed, 17 Nov 2021 00:00:00 +0900',
#   'updated_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=16, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=320, tm_isdst=0)},
#  'headers': {'connection': 'close',
#   'content-length': '1340',
#   'server': 'GitHub.com',
#   'content-type': 'application/xml',
#   'permissions-policy': 'interest-cohort=()',
#   'last-modified': 'Wed, 17 Nov 2021 17:53:14 GMT',
#   'access-control-allow-origin': '*',
#   'strict-transport-security': 'max-age=31556952',
#   'etag': 'W/"6195418a-14c7"',
#   'expires': 'Wed, 17 Nov 2021 19:01:24 GMT',
#   'cache-control': 'max-age=600',
#   'content-encoding': 'gzip',
#   'x-proxy-cache': 'MISS',
#   'x-github-request-id': '4EC0:18DE:856C05:8F0655:61954F2C',
#   'accept-ranges': 'bytes',
#   'date': 'Wed, 17 Nov 2021 18:52:34 GMT',
#   'via': '1.1 varnish',
#   'age': '0',
#   'x-served-by': 'cache-icn1450081-ICN',
#   'x-cache': 'MISS',
#   'x-cache-hits': '0',
#   'x-timer': 'S1637175154.934387,VS0,VE180',
#   'vary': 'Accept-Encoding',
#   'x-fastly-request-id': '53afc15cfb0755714b2721ad178a3979569b4ccb'},
#  'etag': 'W/"6195418a-14c7"',
#  'updated': 'Wed, 17 Nov 2021 17:53:14 GMT',
#  'updated_parsed': time.struct_time(tm_year=2021, tm_mon=11, tm_mday=17, tm_hour=17, tm_min=53, tm_sec=14, tm_wday=2, tm_yday=321, tm_isdst=0),
#  'href': 'https://ingu627.github.io/feed.xml',
#  'status': 200,
#  'encoding': 'utf-8',
#  'version': 'rss20',
#  'namespaces': {'': 'http://www.w3.org/2005/Atom'}}

# %%
import feedparser 
poeun_blog_rss_url = "https://ingu627.github.io/feed.xml" 
rss_feed = feedparser.parse(poeun_blog_rss_url)

latest_blog_post_list = "" 

MAX_POST_NUM = 5

for idx, feed in enumerate(rss_feed['entries']): 
    if idx > MAX_POST_NUM: 
        break 
    feed_date = feed['published_parsed'] 
    latest_blog_post_list += f"[{feed_date.tm_year}/{feed_date.tm_mon}/{feed_date.tm_mday} - {feed['title']}]({feed['link']}) <br>\n" 

markdown_text = """


""" 

readme_text = f"{markdown_text}{latest_blog_post_list}" 

with open("README.md", 'w', encoding='utf-8') as f: 
    f.write(readme_text)
